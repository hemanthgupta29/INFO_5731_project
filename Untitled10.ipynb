# %% [markdown]
# ''' This would be a dataset to work on user reviews
# This dataset has user reviews on phones of different brand phones, with ratings,review votes
# '''

# %%
# Load data
import pandas as pd
df=pd.read_csv('/content/covid19_tweets.csv')
input_df= df.head(5000)
print(input_df.head())
# Out:
#          user_name         user_location  ...               source is_retweet
# 0           ᏉᎥ☻լꂅϮ            astroworld  ...   Twitter for iPhone      False
# 1    Tom Basile 🇺🇸          New York, NY  ...  Twitter for Android      False
# 2  Time4fisticuffs      Pewee Valley, KY  ...  Twitter for Android      False
# 3      ethel mertz  Stuck in the Middle   ...   Twitter for iPhone      False
# 4         DIPR-J&K     Jammu and Kashmir  ...  Twitter for Android      False
#
# [5 rows x 13 columns]

# %% [markdown]
# EDA - Exploratory data analysis

# %%
# Find the shape of the dataset
input_df.shape
# Out:
# (5000, 13)

# %%
# Find the basic info of the dataset, to check if there are any null values
input_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_name         5000 non-null   object
#  1   user_location     4018 non-null   object
#  2   user_description  4728 non-null   object
#  3   user_created      5000 non-null   object
#  4   user_followers    5000 non-null   int64
#  5   user_friends      5000 non-null   int64
#  6   user_favourites   5000 non-null   int64
#  7   user_verified     5000 non-null   bool
#  8   date              5000 non-null   object
#  9   text              5000 non-null   object
#  10  hashtags          3495 non-null   object
#  11  source            5000 non-null   object
#  12  is_retweet        5000 non-null   bool
# dtypes: bool(2), int64(3), object(8)
# memory usage: 439.6+ KB

# %%
#null values are present in the dataset as the shape and nonnull values from the info() dot match
print(input_df.isnull().sum())
# Dropping the null values
input_df=input_df.dropna()
# Out:
# user_name              0
# user_location        982
# user_description     272
# user_created           0
# user_followers         0
# user_friends           0
# user_favourites        0
# user_verified          0
# date                   0
# text                   0
# hashtags            1505
# source                 0
# is_retweet             0
# dtype: int64

# %% [markdown]
# Data Cleaning

# %%
#steps involving all the basic steps of preprocessing
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize  
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
stop_words=stopwords.words("english")
# cleaning the text data
input_df['cleaned_data'] = input_df['text'].str.replace(r"\W", " ").str.strip()# 1.To remove special characters and punctuations
input_df['cleaned_data'] = input_df['cleaned_data'].str.replace(r'\d+',"") #2.To remove Numbers
input_df['cleaned_data'] = input_df['cleaned_data'].apply(lambda x: " ".join(x.lower() for x in x.split())) #convert the whole text into lower case
input_df['cleaned_data'] = input_df['cleaned_data'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words)) #remove all stop words
#input_df['cleaned text review'] # dataframe column that would be used for further process
input_df

#data cleaning for Labels
input_df['labels'] = input_df['user_description'].str.replace(r"\W", " ").str.strip()# 1.To remove special characters and punctuations
input_df['labels'] = input_df['labels'].apply(lambda x: " ".join(x.lower() for x in x.split())) #convert the whole text into lower case
input_df
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                           user_name  ...                                             labels
# 2                   Time4fisticuffs  ...  christian catholic conservative reagan republi...
# 3                       ethel mertz  ...        browns indians clevelandproud _ cavs resist
# 4                          DIPR-J&K  ...  official twitter handle of department of infor...
# 5                  🎹 Franz Schubert  ...  новоро ссия novorossiya оставайсядома stayatho...
# 6                      hr bartender  ...  workplace tips and advice served up in a frien...
# ...                             ...  ...                                                ...
# 4991            Daily Express Sabah  ...  official twitter account of daily express saba...
# 4992                    #Nozulu ...  ...  retired amateur football fan husband father of...
# 4994  Sue Reeve 🇪🇺🇪🇺♥️🧡💛💚💙💜🏳️‍🌈🏳️‍🌈  ...  londoner now living in glasgow suburbs via the...
# 4998                     Don Ziyech  ...                blue is the color messi is the goat
# 4999            Isosceles Sheffield  ...  outsourced finance payroll hr teams fd cfo ser...
#
# [2742 rows x 15 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.9, min_df=25, token_pattern='\w+|\$[\d\.]+|\S+')

# apply transformation
tf = vectorizer.fit_transform(input_df['cleaned_data']).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()

# %%
import sys
sys.path.insert(1,'/content/')

# %% [markdown]
# LDA TEXT MODELLING

# %%
from sklearn.decomposition import LatentDirichletAllocation
import pandas as pd
def LDA_MODEL(number_of_topics,tf,feature_names, no_top_words):
  number_of_topics = 2
  model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)
  model.fit(tf)
  return display_topics(model,feature_names, no_top_words)
  pass

def display_topics(model, feature_names, no_top_words):
  topic_dict = {}
  for topic_idx, topic in enumerate(model.components_):
    topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i]) for i in topic.argsort()[:-no_top_words - 1:-1]]
    topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i]) for i in topic.argsort()[:-no_top_words - 1:-1]]
  return pd.DataFrame.from_dict(topic_dict)

# %%
#import AlgorithmLDA as lda_ul
result = LDA_MODEL(10,tf,tf_feature_names,10)
result
# Out:
#   Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights
# 0         covid           752.6         covid          1624.4
# 1         cases           248.1           new           128.6
# 2   coronavirus           162.6      positive           127.4
# 3           amp           133.3        people           121.2
# 4      pandemic           118.2        health           114.3
# 5        spread           108.5   coronavirus            93.4
# 6          help           106.4            us            83.3
# 7          risk           100.5        deaths            81.4
# 8          even            92.5         cases            77.9
# 9         daily            86.5         today            73.4

# %%
import matplotlib.pyplot as plt
columns_list = ["Topic "+str(i)+" weights" for i in range(0,2)]
for i in columns_list:
  result[i] = pd.to_numeric(result[i])
result.hist(figsize=(10,10),color = 'Purple')
plt.show(block=False)

# %%
result.plot(kind='density', subplots=True,layout = (2,2),sharex=False, legend=True, fontsize=1,figsize=(15,15))
plt.show(block=False)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors
my_stopwords = nltk.corpus.stopwords.words('english')

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=my_stopwords,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

columns_list = ["Topic "+str(i)+" words" for i in range(0,2)]
topics = list()

for i in columns_list:
  topics.append(result[i].values)

frequencies = list()
columns_list = ["Topic "+str(i)+" weights" for i in range(0,2)]

for i in columns_list:
  frequencies.append(result[i].values)


fig, axes = plt.subplots(2,1, figsize=(15,15), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    size_of_array = len(topics[i])
    topic_words = dict()
    for j in range(size_of_array):
      topic_words[topics[i][j]] = frequencies[i][j]
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# LSA TOPIC MODELLING

# %%
from sklearn.decomposition import TruncatedSVD
import pandas as pd

def LSA_MODEL(tf,vectorizer):
  svd_model = TruncatedSVD(n_components=1, algorithm ='randomized', n_iter=100, random_state=122)
  svd_model.fit(tf)
  terms = vectorizer.get_feature_names()
  df = pd.DataFrame()
  for i, comp in enumerate(svd_model.components_):
    term_comp = zip(terms,comp)
    sorted_terms = sorted(term_comp, key = lambda x:x[1], reverse = True)[:7]
    str1 = "Topic "+str(i)
    str2 = str1 + " weights"
    str1_list = list()
    str2_list = list()
    for j in sorted_terms:
      str1_list.append(j[0])
      str2_list.append(j[1])
    df[str1] = str1_list
    df[str2] = str2_list
  return df

# %%
#import AlgorithmLSA as lsa
lsa_result=LSA_MODEL(tf,vectorizer)
lsa_result
# Out:
#        Topic 0  Topic 0 weights
# 0        covid         0.957980
# 1        cases         0.147579
# 2  coronavirus         0.086238
# 3          new         0.084026
# 4       spread         0.050895
# 5     positive         0.048400
# 6         help         0.046385

# %%
columns_list = ["Topic "+str(i)+" weights" for i in range(1)]
for i in columns_list:
  lsa_result[i] = pd.to_numeric(lsa_result[i])
lsa_result.hist(figsize=(15,15),color = 'purple')
plt.show(block=False)

# %%
lsa_result.plot(kind='density', subplots=True,layout = (5,5),sharex=False, legend=True, fontsize=1,figsize=(15,15))
plt.show(block=False)

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'
cols = cols*2
cloud = WordCloud(stopwords=my_stopwords,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

columns_list = ["Topic "+str(i) for i in range(0,1)]
topics = list()

for i in columns_list:
  topics.append(lsa_result[i].values)

frequencies = list()
columns_list = ["Topic "+str(i)+" weights" for i in range(0,1)]

for i in columns_list:
  frequencies.append(lsa_result[i].values)


fig, axes = plt.subplots(2,1, figsize=(15,15), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    size_of_array = len(topics[0])
    topic_words = dict()
    for j in range(size_of_array):
      topic_words[topics[0][j]] = frequencies[0][j]
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# HMM-LDA TOPIC MODELLING

# %%
#import AlgorithmHMMLDA as HMMLDA
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
import time

from six.moves import xrange
import numpy as np
from scipy.special import gammaln

class BaseTopicModel(object):
    def __init__(self, n_doc, n_voca, **kwargs):
        self.n_doc = n_doc
        self.n_voca = n_voca
        self.verbose = kwargs.pop('verbose', True)

class BaseGibbsParamTopicModel(BaseTopicModel):


    def __init__(self, n_doc, n_voca, n_topic, alpha, beta, **kwargs):
        super(BaseGibbsParamTopicModel, self).__init__(n_doc=n_doc, n_voca=n_voca, **kwargs)
        self.n_topic = n_topic
        self.TW = np.zeros([self.n_topic, self.n_voca])
        self.DT = np.zeros([self.n_doc, self.n_topic])
        self.sum_T = np.zeros(self.n_topic)

        self.alpha = alpha
        self.beta = beta

        self.topic_assignment = list()

        self.TW += self.beta
        self.sum_T += self.beta * self.n_voca
        self.DT += self.alpha

class HMM_LDA(BaseGibbsParamTopicModel):
 

    def __init__(self, n_doc, n_voca, n_topic, alpha, beta, **kwargs):
        super(BaseGibbsParamTopicModel, self).__init__(n_doc=n_doc, n_voca=n_voca, **kwargs)
        self.n_topic = n_topic
        self.TW = np.zeros([self.n_topic, self.n_voca])
        self.DT = np.zeros([self.n_doc, self.n_topic])
        self.sum_T = np.zeros(self.n_topic)

        self.alpha = alpha
        self.beta = beta

        self.topic_assignment = list()

        self.TW += self.beta
        self.sum_T += self.beta * self.n_voca
        self.DT += self.alpha

class HMM_LDA(BaseGibbsParamTopicModel):

    def __init__(self, n_docs, n_voca, n_topic, n_class, alpha=0.1, beta=0.01, gamma=0.1, eta=0.1, **kwargs):
        super(HMM_LDA, self).__init__(n_docs, n_voca, n_topic, alpha, beta, **kwargs)
        self.n_class = n_class

        self.gamma = gamma
        self.eta = eta

        self.CW = np.zeros([self.n_class, self.n_voca]) + self.gamma  # class x word
        self.sum_C = np.zeros([self.n_class]) + self.n_voca * self.gamma

        self.T = np.zeros([self.n_class + 2, self.n_class + 2]) + self.eta

        self.word_class = list()
        self.word_topic = list()

    def fit(self, docs, max_iter=100):
        self.random_init(docs)

    def fit(self, docs, max_iter=100):
        self.random_init(docs)
        self.gibbs_sampling(docs, max_iter)

    # randomly initialize 
    def random_init(self, docs):

        for di in xrange(self.n_doc):
            doc = docs[di]
            num_sentence = len(doc)

            doc_class = list()
            doc_topic = list()

            for si in xrange(num_sentence):
                sentence_class = list()
                sentence_topic = list()

                sentence = doc[si]
                len_sentence = len(sentence)

                for wi in xrange(len_sentence):
                    word = sentence[wi]
                    c = np.random.randint(self.n_class)

                    sentence_class.append(c)
                    self.CW[c, word] += 1
                    self.sum_C[c] += 1
                    if wi == 0:  # if the first word
                        self.T[self.n_class, c] += 1
                    else:
                        self.T[sentence_class[wi - 1], c] += 1

                    if wi == len_sentence - 1:  # the last word
                        self.T[c, self.n_class + 1] += 1

                    k = np.random.randint(self.n_topic)
                    sentence_topic.append(k)
                    self.DT[di, k] += 1
                    if c == 0:
                        self.TW[k, word] += 1
                        self.sum_T[k] += 1

                doc_class.append(sentence_class)
                doc_topic.append(sentence_topic)

            self.word_class.append(doc_class)
            self.word_topic.append(doc_topic)

    def gibbs_sampling(self, docs, max_iter):

        for iter in xrange(max_iter):
            tic = time.time()
            for di, doc in enumerate(docs):
                doc_topic = self.word_topic[di]
                doc_class = self.word_class[di]

                for si, sentence in enumerate(doc):
                    len_sentence = len(sentence)

                    sentence_topic = doc_topic[si]
                    sentence_class = doc_class[si]

                    for wi, word in enumerate(sentence):

                        if wi == 0:
                            prev_c = self.n_class
                        else:
                            prev_c = sentence_class[wi - 1]

                        if wi == len_sentence - 1:
                            next_c = self.n_class + 1
                        else:
                            next_c = sentence_class[wi + 1]

                        old_c = sentence_class[wi]
                        old_t = sentence_topic[wi]

                        # remove previous state
                        self.CW[old_c, word] -= 1
                        self.sum_C[old_c] -= 1
                        self.T[prev_c, old_c] -= 1
                        self.T[old_c, next_c] -= 1

                        # sample class
                        prob = (self.T[prev_c, :self.n_class] / self.T[prev_c].sum()) \
                                * (self.T[:self.n_class, next_c] / np.sum(self.T[:self.n_class], 1))
                        prob[0] *= (self.TW[old_t, word] / self.sum_T[old_t])
                        prob[1:] *= self.CW[1:, word] / self.sum_C[1:]

                        new_c = np.random.multinomial(1, prob).argmax()

                        sentence_class[wi] = new_c
                        self.CW[new_c, word] += 1
                        self.sum_C[new_c] += 1
                        self.T[prev_c, new_c] += 1
                        self.T[new_c, next_c] += 1

                        # remove previous topic state
                        self.DT[di, old_t] -= 1
                        if old_c == 0:
                            self.TW[old_t, word] -= 1
                            self.sum_T[old_t] -= 1

                        # sample topic
                        prob = self.DT[di].copy()
                        if new_c == 0:
                            prob *= self.TW[:, word] / self.sum_T
                        prob /= np.sum(prob)

                        new_topic = np.random.multinomial(1, prob).argmax()
                        self.DT[di, new_topic] += 1
                        if new_c == 0:
                            self.TW[new_topic, word] += 1
                            self.sum_T[new_topic] += 1
                        sentence_topic[wi] = new_topic

            if self.verbose:
                ll = self.log_likelihood()
                logger.info('[ITER] %d,\telapsed time: %.2f\tlog-likelihood:%.2f', iter, time.time() - tic, ll)

    def log_likelihood(self):

        ll = self.n_doc * gammaln(self.alpha * self.n_topic)
        ll -= self.n_doc * self.n_topic * gammaln(self.alpha)
        ll += self.n_topic * gammaln(self.beta * self.n_voca)
        ll -= self.n_topic * self.n_voca * gammaln(self.beta)

        for di in xrange(self.n_doc):
            ll += gammaln(self.DT[di]).sum() - gammaln(self.DT[di].sum())
        for ki in xrange(self.n_topic):
            ll += gammaln(self.TW[ki]).sum() - gammaln(self.sum_T[ki])

        if self.n_class != 1:
            ll += (self.n_class - 1) * gammaln(self.gamma * (self.n_class - 1))
            ll -= (self.n_class - 1) * self.n_voca * gammaln(self.gamma)
            ll += (self.n_class + 2) * gammaln(self.eta * (self.n_class + 2))
            ll -= (self.n_class + 2) * (self.n_class + 2) * gammaln(self.eta)

            for ci in xrange(1, self.n_class):
                ll += gammaln(self.CW[ci]).sum() - gammaln(self.sum_C[ci])
            for ci in xrange(self.n_class + 2):
                ll += gammaln(self.T[ci]).sum() - gammaln(self.T[ci].sum())

        return ll

# %%
def get_reuters_token_list_by_sentence(num_doc,ip):
    corpus = [[i.split() for i in ip ]]
    print(corpus)
    valid_voca = set(w.lower() for w in nltk.corpus.words.words())
    stop = stopwords.words('english')
    valid_voca = valid_voca.union(stop)

    tmp_corpus = list()
    voca_dic = dict()
    voca = list()
    for doc in corpus:
        tmp_doc = list()
        for sent in doc:
            tmp_sent = list()
            for word in sent:
                if word in valid_voca:
                    tmp_sent.append(word)
                    if word not in voca_dic:
                        voca_dic[word] = len(voca_dic)
                        voca.append(word)
            if len(tmp_sent) > 0:
                tmp_doc.append(tmp_sent)
        if len(tmp_doc) > 0:
            tmp_corpus.append(tmp_doc)

     # convert token list to word index list
    corpus = list()
    for doc in tmp_corpus:
        new_doc = list()
        for sent in doc:
            new_sent = list()
            for word in sent:
                new_sent.append(voca_dic[word])
            new_doc.append(new_sent)
        corpus.append(new_doc)

    return np.array(voca), corpus

# %%
n_docs = 1000
voca, corpus = get_reuters_token_list_by_sentence(n_docs,input_df["cleaned_data"].values)
# Out:
# [[['diane', 'wdunlap', 'realdonaldtrump', 'trump', 'never', 'claimed', 'covid', 'hoax', 'claim', 'effort', 'https', 'co', 'jkkvhwhb'], ['brookbanktv', 'one', 'gift', 'covid', 'give', 'appreciation', 'simple', 'things', 'always', 'around', 'https', 'co', 'zpoalfxcw'], ['july', 'media', 'bulletin', 'novel', 'coronavirusupdates', 'covid', 'kansalrohit', 'drsyedsehrish', 'airnewsalerts', 'ani', 'https', 'co', 'mneecsjhh'], ['coronavirus', 'covid', 'deaths', 'continue', 'rise', 'almost', 'bad', 'ever', 'politicians', 'businesses', 'want', 'https', 'co', 'hxmhooxxc'], ['covid', 'change', 'work', 'general', 'recruiting', 'specifically', 'via', 'proactivetalent', 'recruiting', 'https', 'co', 'bjzxzgpmbk'], ['pope', 'god', 'prophet', 'sadhu', 'sundar', 'selvaraj', 'watch', 'https', 'co', 'xrtykvji', 'hurricanehanna', 'covid', 'https', 'co', 'dzcgunwl'], ['order', 'https', 'co', 'nurgxema', 'logo', 'graphicdesigner', 'logodesign', 'logodesinger', 'icon', 'minimalist', 'abstract', 'https', 'co', 'ypmogqis'], ['pattyhajdu', 'navdeepsbains', 'one', 'safe', 'covid', 'everyone', 'safe', 'commit', 'ensure', 'https', 'co', 'awcjoekvc'], ['let', 'protect', 'covid', 'real', 'numbers', 'climbing', 'fast', 'continent', 'let', 'n', 'https', 'co', 'bymsfxltrw'], ['nagaland', 'police', 'covid', 'awareness', 'city', 'tower', 'junction', 'dimapur', 'covid', 'keepsocialdistance', 'https', 'co', 'wovfmqhueo'], ['second', 'wave', 'covid', 'flanders', 'back', 'homework', 'https', 'co', 'swimzacmn'], ['first', 'comprehensive', 'review', 'wash', 'amp', 'covid', 'analysis', 'key', 'ways', 'wash', 'help', 'reduce', 'transmission', 'https', 'co', 'ecsfdmob'], ['holy', 'water', 'times', 'covid', 'https', 'co', 'yazyxl'], ['kolar', 'need', 'blood', 'type', 'b', 'positive', 'jalappa', 'hospital', 'blood', 'component', 'need', 'plasma', 'b', 'covid', 'recove', 'https', 'co', 'xtgxulcz'], ['munitions', 'response', 'team', 'bosniaandherzegovina', 'modified', 'ops', 'adopted', 'masks', 'disinfectants', 'sanitizers', 'https', 'co', 'lmbkxlwwq'], ['imagine', 'people', 'profiting', 'human', 'suffering', 'covid', 'studying', 'maps', 'make', 'https', 'co', 'nelsmgjuh'], ['tncoronaupdate', 'tn', 'crosses', 'lakh', 'mark', 'ppp', 'recovered', 'far', 'covid', 'positive', 'today', 'total', 'https', 'co', 'qdjkpccqv'], ['actor', 'vishalkofficial', 'father', 'mr', 'g', 'k', 'reddy', 'tested', 'positive', 'covid', 'days', 'back', 'vishal', 'https', 'co', 'vlonrlwy'], ['update', 'total', 'covid', 'cases', 'recoveries', 'deaths', 'reported', 'countries', 'africa', 'see', 'total', 'numb', 'https', 'co', 'eqcjehwri'], ['unionwill', 'megawedgy', 'jjhorgan', 'regarding', 'community', 'outbreak', 'covid', 'haida', 'gwaii', 'cases', 'one', 'recover', 'https', 'co', 'rjzuyqy'], ['nicolekowalski', 'chrisdameanor', 'feeling', 'little', 'anxious', 'covid', 'seems', 'detracted', 'everyone', 'https', 'co', 'amhdxamlg'], ['jfoster', 'bbclaurak', 'well', 'borisjohnson', 'might', 'understood', 'missed', 'cobra', 'meeting', 'five', 'https', 'co', 'mqpagcygn'], ['released', 'two', 'new', 'covid', 'podcast', 'episodes', 'week', 'technology', 'platforms', 'used', 'conduct', 'telehealth', 'visits', 'c', 'https', 'co', 'gveyvczk'], ['playyourpart', 'fight', 'covid', 'one', 'us', 'make', 'difference', 'containing', 'spread', 'lets', 'https', 'co', 'frzlgrsqf'], ['britain', 'understand', 'covid', 'months', 'plenty', 'countries', 'understand', 'took', 'effective', 'https', 'co', 'kvcaqskz'], ['volume', 'back', 'please', 'covid', 'https', 'co', 'dpnbvhx'], ['delhi', 'reports', 'covid', 'positive', 'cases', 'deaths', 'saturday', 'death', 'toll', 'rises', 'reports', 'ani', 'quot', 'https', 'co', 'jxsvpwmrqs'], ['tamilnadu', 'covid', 'th', 'july', 'tn', 'highest', 'spike', 'total', 'cases', 'chennai', 'https', 'co', 'xzguzcgr'], ['nytimes', 'reporting', 'yesterday', 'people', 'died', 'covid', 'usa', 'k', 'new', 'cases', 'reported', 'serio', 'https', 'co', 'sfwpvfeb'], ['crazy', 'world', 'come', 'americans', ' ...

# %%
n_voca = len(voca)
n_topic = 2
n_class = 2
max_iter = 100
model = HMM_LDA(len(corpus), n_voca, n_topic, n_class, alpha=0.1, beta=0.1, gamma=0.1, eta=0.1, verbose=False)
model.fit(corpus, max_iter=max_iter)

# %%
def get_top_words(topic_word_matrix, vocab, topic, n_words=2):
    if not isinstance(vocab, np.ndarray):
        vocab = np.array(vocab)
    top_words = vocab[topic_word_matrix[topic].argsort()[::-1][:n_words]]
    return top_words

# %%
for ti in range(n_topic):
    top_words = get_top_words(model.TW, voca, ti, n_words=10)
    print('Topic', ti ,': ', ','.join(top_words))
# Out:
# Topic 0 :  covid,sooner,pandemic,people,even,today,total,day,positive,health
# Topic 1 :  covid,total,self,india,day,year,health,people,even,positive

# %% [markdown]
# Supervised LDA TOPIC MODELLING

# %%
# !pip install pymc
# Out:
# Collecting pymc
#   Downloading https://files.pythonhosted.org/packages/37/81/9a222c38c65019de9ad5a1ee2448cc4a9b5f7a64eeaf246c77f81c0e6f94/pymc-2.3.8.tar.gz (385kB)
#      |████████████████████████████████| 389kB 6.6MB/s
# Building wheels for collected packages: pymc
#   Building wheel for pymc (setup.py) ... done
#   Created wheel for pymc: filename=pymc-2.3.8-cp37-cp37m-linux_x86_64.whl size=1352867 sha256=e25f9cd2835afeccbdbb7aab21fc7ec1125b3afefffade443d1fa0df841874cb
#   Stored in directory: /root/.cache/pip/wheels/0b/a8/e7/8f3ba91a39294d538a92db052fd1fcba1fca74a58c8b022026
# Successfully built pymc
# Installing collected packages: pymc
# Successfully installed pymc-2.3.8

# %%
from __future__ import print_function

import numpy as np
from scipy.special import gammaln
from scipy.stats import norm
from numpy.linalg import solve
from six.moves import xrange

import numpy as np


import numpy as np

from six.moves import xrange


def sampling_from_dist(prob):
    """ Sample index from a list of unnormalised probability distribution
        same as np.random.multinomial(1, prob/np.sum(prob)).argmax()
    Parameters
    ----------
    prob: ndarray
        array of unnormalised probability distribution
    Returns
    -------
    new_topic: return a sampled index
    """
    thr = prob.sum() * np.random.rand()
    new_topic = 0
    tmp = prob[new_topic]
    while tmp < thr:
        new_topic += 1
        tmp += prob[new_topic]
    return new_topic


def sampling_from_dict(prob):
    """ sample key from dictionary `prob` where values are unnormalised probability distribution
    Parameters
    ----------
    prob: dict
        key = topic
        value = unnormalised probability of the topic
    Returns
    -------
    key: int
        sampled key
    """
    prob_sum = sum(prob.values())

    thr = prob_sum * np.random.rand()
    tmp = 0
    for key, p in prob.items():
        tmp += p
        if tmp < thr:
            new_topic = key
    return new_topic


def isfloat(value):
    """
    Check the value is convertable to float value
    """
    try:
        float(value)
        return True
    except ValueError:
        return False


def read_voca(path):
    """
    open file from path and read each line to return the word list
    """
    with open(path, 'r') as f:
        return [word.strip() for word in f.readlines()]


def word_cnt_to_bow_list(word_ids, word_cnt):
    corpus_list = list()
    for di in xrange(len(word_ids)):
        doc_list = list()
        for wi in xrange(len(word_ids[di])):
            word = word_ids[di][wi]
            for c in xrange(word_cnt[di][wi]):
                doc_list.append(word)
        corpus_list.append(doc_list)
    return corpus_list


def log_normalize(log_prob_vector):
    """
    returns a probability vector of log probability vector
    """
    max_v = log_prob_vector.max()
    log_prob_vector += max_v
    log_prob_vector = np.exp(log_prob_vector)
    log_prob_vector /= log_prob_vector.sum()
    return log_prob_vector


def convert_cnt_to_list(word_ids, word_cnt):
    corpus = list()

    for di in xrange(len(word_ids)):
        doc = list()
        doc_ids = word_ids[di]
        doc_cnt = word_cnt[di]
        for wi in xrange(len(doc_ids)):
            word_id = doc_ids[wi]
            for si in xrange(doc_cnt[wi]):
                doc.append(word_id)
        corpus.append(doc)
    return corpus


def write_top_words(topic_word_matrix, vocab, filepath, n_words=20, delimiter=',', newline='\n'):
    with open(filepath, 'w') as f:
        for ti in xrange(topic_word_matrix.shape[0]):
            top_words = vocab[topic_word_matrix[ti, :].argsort()[::-1][:n_words]]
            f.write('%d' % (ti))
            for word in top_words:
                f.write(delimiter + word)
            f.write(newline)


def get_top_words(topic_word_matrix, vocab, topic, n_words=20):
    if not isinstance(vocab, np.ndarray):
        vocab = np.array(vocab)
    top_words = vocab[topic_word_matrix[topic].argsort()[::-1][:n_words]]
    return top_words

class BaseTopicModel(object):
    """
    Attributes
    ----------
    n_doc: int
        the number of total documents in the corpus
    n_voca: int
        the vocabulary size of the corpus
    verbose: boolean
        if True, print each iteration step while inference.
    """
    def __init__(self, n_doc, n_voca, **kwargs):
        self.n_doc = n_doc
        self.n_voca = n_voca
        self.verbose = kwargs.pop('verbose', True)


class BaseGibbsParamTopicModel(BaseTopicModel):
    """ Base class of parametric topic models with Gibbs sampling inference
    Attributes
    ----------
    n_topic: int
        a number of topics to be inferred through the Gibbs sampling
    TW: ndarray, shape (n_voca, n_topic)
        word-topic matrix, keeps the number of assigned word tokens for each word-topic pair
    DT: ndarray, shape (n_doc, n_topic)
        document-topic matrix, keeps the number of assigned word tokens for each document-topic pair
    sum_T: ndarray, shape (n_topic)
        number of word tokens assigned for each topic
    alpha: float
        symmetric parameter of Dirichlet prior for document-topic distribution
    beta: float
        symmetric parameter of Dirichlet prior for topic-word distribution
    """

    def __init__(self, n_doc, n_voca, n_topic, alpha, beta, **kwargs):
        super(BaseGibbsParamTopicModel, self).__init__(n_doc=n_doc, n_voca=n_voca, **kwargs)
        self.n_topic = n_topic
        self.TW = np.zeros([self.n_topic, self.n_voca])
        self.DT = np.zeros([self.n_doc, self.n_topic])
        self.sum_T = np.zeros(self.n_topic)

        self.alpha = alpha
        self.beta = beta

        self.topic_assignment = list()

        self.TW += self.beta
        self.sum_T += self.beta * self.n_voca
        self.DT += self.alpha

class SupervisedLDA(BaseGibbsParamTopicModel):
    """ Supervised LDA with Gaussian response variables
    Attributes
    ----------
    eta: ndarray, shape (n_topic)
        coefficient parameter of Gaussian distribution where the mean is np.dot(z_bar.T, eta)
    sigma: float
        variance parameter of Gaussian output variables
    """

    def __init__(self, n_doc, n_voca, n_topic, alpha=0.1, beta=0.01, sigma=1., **kwargs):
        super(SupervisedLDA, self).__init__(n_doc=n_doc, n_voca=n_voca, n_topic=n_topic, alpha=alpha, beta=beta,
                                                 **kwargs)
        self.eta = np.random.normal(scale=5, size=self.n_topic)
        self.sigma = sigma

    def random_init(self, docs):
        """
        Random initialization of topics
        Parameters
        ----------
        docs:
        """
        for di in xrange(len(docs)):
            doc = docs[di]
            topics = np.random.randint(self.n_topic, size=len(doc))
            self.topic_assignment.append(topics)

            for wi in xrange(len(doc)):
                topic = topics[wi]
                word = doc[wi]
                self.TW[topic, word] += 1
                self.sum_T[topic] += 1
                self.DT[di, topic] += 1

    def fit(self, docs, responses, max_iter=100):
        """ Stochastic Expectation Maximisation algorithm
        """
        self.random_init(docs)
        for iteration in xrange(max_iter):

            for di in xrange(len(docs)):
                doc = docs[di]
                for wi in xrange(len(doc)):
                    word = doc[wi]
                    old_topic = self.topic_assignment[di][wi]

                    self.TW[old_topic, word] -= 1
                    self.sum_T[old_topic] -= 1
                    self.DT[di, old_topic] -= 1

                    z_bar = np.zeros([self.n_topic, self.n_topic]) + self.DT[di, :] + np.identity(self.n_topic)
                    # this seems more straightforward than z_bar/z_bar.sum(1)
                    z_bar /= self.DT[di, :].sum() + 1

                    # update
                    prob = (self.TW[:, word]) / (self.sum_T) * (self.DT[di, :]) * np.exp(
                        np.negative((responses[di] - np.dot(z_bar, self.eta)) ** 2) / 2 / self.sigma)

                    new_topic = sampling_from_dist(prob)

                    self.topic_assignment[di][wi] = new_topic
                    self.TW[new_topic, word] += 1
                    self.sum_T[new_topic] += 1
                    self.DT[di, new_topic] += 1

            # estimate parameters
            z_bar = self.DT / self.DT.sum(1)[:, np.newaxis]  # DxK
            self.eta = solve(np.dot(z_bar.T, z_bar), np.dot(z_bar.T, responses))

            # compute mean absolute error
            mae = np.mean(np.abs(responses - np.dot(z_bar, self.eta)))
            #if self.verbose:
             #   logger.info('[ITER] %d,\tMAE:%.2f,\tlog_likelihood:%.2f', iteration, mae,
              #              self.log_likelihood(docs, responses))

    def sample_heldout_doc(self, max_iter, heldout_docs):
        h_doc_topics = list()
        h_doc_topic_sum = np.zeros([len(heldout_docs), self.n_topic]) + self.alpha

        # random init
        for di in xrange(len(heldout_docs)):
            doc = heldout_docs[di]
            topics = np.random.randint(self.n_topic, size=len(doc))
            h_doc_topics.append(topics)
            for wi in xrange(len(doc)):
                topic = topics[wi]
                h_doc_topic_sum[di, topic] += 1

        for iter in xrange(max_iter):
            for di in xrange(len(heldout_docs)):
                doc = heldout_docs[di]
                for wi in xrange(len(doc)):
                    word = doc[wi]
                    old_topic = h_doc_topics[di][wi]

                    h_doc_topic_sum[di, old_topic] -= 1

                    # update
                    prob = (self.TW[:, word] / self.sum_T) * (self.DT[di, :])

                    new_topic = sampling_from_dist(prob)

                    h_doc_topics[di][wi] = new_topic
                    h_doc_topic_sum[di, new_topic] += 1

        return h_doc_topic_sum

    def log_likelihood(self, docs, responses):
        """
        likelihood function
        """
        ll = 0

        ll += len(docs) * gammaln(self.alpha * self.n_topic)
        ll -= len(docs) * self.n_topic * gammaln(self.alpha)
        ll += self.n_topic * gammaln(self.beta * self.n_voca)
        ll -= self.n_topic * self.n_voca * gammaln(self.beta)

        for di in xrange(self.n_doc):
            ll += gammaln(self.DT[di, :]).sum() - gammaln(self.DT[di, :].sum())
            z_bar = self.DT[di] / np.sum(self.DT[di])
            mean = np.dot(z_bar, self.eta)
            ll += norm.logpdf(responses[di], mean, np.sqrt(self.sigma))
        for ki in xrange(self.n_topic):
            ll += gammaln(self.TW[ki, :]).sum() - gammaln(self.TW[ki, :].sum())

        return ll

# %%
training_data = input_df['cleaned_data'].values

# %%
import nltk
from nltk import word_tokenize
from nltk.corpus import reuters, stopwords
from six.moves import xrange
from collections import Counter
nltk.download('words')

def get_ids_cnt(corpus, max_voca=9999999, remove_top_n=5):
    voca = set(w.lower() for w in nltk.corpus.words.words())
    stop = stopwords.words('english')

    docs = list()
    freq = Counter()

    for doc in corpus:
        if isinstance(doc, str):
            doc = word_tokenize(doc)
        elif not hasattr(doc, '__iter__'):
            raise Exception('Corpus is not a list of string or token list')

        # remove word using stopword list or single character word
        doc = [word.lower() for word in doc if word.lower() in voca and word.lower() not in stop and len(word) != 1]
        freq.update(doc)
        docs.append(doc)

    voca = [key for iter, (key, val) in enumerate(freq.most_common(max_voca)) if iter >= remove_top_n]

    voca_dic = dict()
    voca_list = list()
    for word in voca:
        voca_dic[word] = len(voca_dic)
        voca_list.append(word)

    doc_ids = list()
    doc_cnt = list()

    for doc in docs:
        words = set(doc)
        ids = np.array([int(voca_dic[word]) for word in words if word in voca_dic])
        cnt = np.array([int(doc.count(word)) for word in words if word in voca_dic])

        doc_ids.append(ids)
        doc_cnt.append(cnt)

    return np.array(voca_list), doc_ids, doc_cnt
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
voca, word_ids, word_cnt = get_ids_cnt(training_data)

# %%
def convert_cnt_to_list(word_ids, word_cnt):
    corpus = list()

    for di in xrange(len(word_ids)):
        doc = list()
        doc_ids = word_ids[di]
        doc_cnt = word_cnt[di]
        for wi in xrange(len(doc_ids)):
            word_id = doc_ids[wi]
            for si in xrange(doc_cnt[wi]):
                doc.append(word_id)
        corpus.append(doc)
    return corpus

# %%
corpus = convert_cnt_to_list(word_ids, word_cnt)

# %%
n_doc = len(corpus)
n_voca = voca.size

# %%
n_doc
# Out:
# 2742

# %%
import random
#fit artificial sevearity
sevearity = [random.randint(0,10) for i in range(0,2742)]

# %%
model = SupervisedLDA(n_doc, n_voca, 10, sigma=0.01)
model.fit(corpus, sevearity)

# %%
for ti in model.eta.argsort():
    top_words = get_top_words(model.TW, voca, ti, n_words=10)
    print('Eta', model.eta[ti] ,'\nTopic', ti ,':\t', ','.join(top_words))
# Out:
# Eta -4.4978884717636705
# Topic 4 :	 even,help,mask,number,july,daily,news,home,wear,risk
# Eta -2.0720728422314822
# Topic 2 :	 need,work,last,since,recovery,days,july,total,back,read
# Eta 0.17633245251860294
# Topic 6 :	 latest,time,obesity,day,year,hospital,world,mask,going,news
# Eta 2.371342284220836
# Topic 8 :	 spread,slow,sooner,self,help,risk,identify,even,daily,health
# Eta 3.8839095501688554
# Topic 3 :	 health,get,us,per,working,public,together,right,million,care
# Eta 5.742737084613004
# Topic 0 :	 spread,sooner,slow,risk,self,help,even,daily,like,virus
# Eta 6.876453248787469
# Topic 9 :	 one,today,local,go,minister,via,contact,government,times,us
# Eta 8.152503114387768
# Topic 1 :	 tested,many,back,july,preprint,good,mr,get,one,actor
# Eta 9.894708609398194
# Topic 5 :	 health,us,day,total,state,like,one,due,blood,need
# Eta 13.147991059951574
# Topic 7 :	 identify,daily,even,help,good,well,plasma,need,still,face

# %% [markdown]
# Bi-Term TOPIC MODELLING

# %%
# !pip install biterm
# Out:
# Collecting biterm
#   Downloading https://files.pythonhosted.org/packages/36/ca/5a43511e6ea8ca02cc9e8be1b8898ad79b140c055d4400342dc210ba23bb/biterm-0.1.5.tar.gz (79kB)
#      |████████████████████████████████| 81kB 3.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from biterm) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from biterm) (4.41.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from biterm) (0.29.22)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from biterm) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->biterm) (1.15.0)
# Building wheels for collected packages: biterm
#   Building wheel for biterm (setup.py) ... done
#   Created wheel for biterm: filename=biterm-0.1.5-cp37-cp37m-linux_x86_64.whl size=195785 sha256=64098e93f319243b69a393b8429e6708111ee4ebbea66a973e1fd26cc0fbde38
#   Stored in directory: /root/.cache/pip/wheels/86/04/10/231fb1d39d86ab58c2683fd3d4fe8415a5bc284ba8a20fd638
# Successfully built biterm
# Installing collected packages: biterm
# Successfully installed biterm-0.1.5

# %%
from biterm.utility import vec_to_biterms
from biterm.cbtm import oBTM
import numpy as np
def BITERM_MODEL(tf, vectorizer):
  vocab = np.array(vectorizer.get_feature_names())
  biterms = vec_to_biterms(tf)
  btm = oBTM(num_topics=20, V= vocab)
  topics = btm.fit_transform(biterms, iterations=100)
  return topics
  pass

# %%
import sys
sys.path.insert(1,'/content/')
#import AlgorithmBITERM as btm_model
topics = BITERM_MODEL(tf,vectorizer)
# Out:
# 100%|██████████| 100/100 [01:06<00:00,  1.50it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':

# %%
topics
# Out:
# array([[9.98811096e-01, 4.28766908e-05, 7.04390289e-05, ...,
#         5.98275590e-07, 6.93957357e-05, 7.24652678e-08],
#        [9.23497193e-01, 2.65820165e-05, 4.37147988e-05, ...,
#         5.60861615e-06, 4.30285702e-05, 6.79335540e-07],
#        [1.92976343e-01, 2.01149926e-05, 1.32512348e-02, ...,
#         2.80672525e-07, 3.25560272e-05, 3.39960547e-08],
#        ...,
#        [9.99018642e-01, 3.53917569e-05, 5.81425698e-05, ...,
#         4.93835318e-07, 5.72814030e-05, 5.98150905e-08],
#        [8.99538323e-01, 4.39133721e-05, 7.23188830e-05, ...,
#         2.11334959e-05, 5.56169077e-03, 2.55976421e-06],
#        [8.83819577e-01, 2.02636979e-05, 3.33042293e-05, ...,
#         1.96127719e-06, 3.34661689e-04, 2.37556870e-07]])

# %%
texts= input_df['cleaned_data'].values
for i in range(len(texts)):
        print("{} (topic: {})".format(texts[i], topics[i].argmax()))
# Out:
# diane wdunlap realdonaldtrump trump never claimed covid hoax claim effort https co jkkvhwhb (topic: 0)
# brookbanktv one gift covid give appreciation simple things always around https co zpoalfxcw (topic: 0)
# july media bulletin novel coronavirusupdates covid kansalrohit drsyedsehrish airnewsalerts ani https co mneecsjhh (topic: 6)
# coronavirus covid deaths continue rise almost bad ever politicians businesses want https co hxmhooxxc (topic: 0)
# covid change work general recruiting specifically via proactivetalent recruiting https co bjzxzgpmbk (topic: 0)
# pope god prophet sadhu sundar selvaraj watch https co xrtykvji hurricanehanna covid https co dzcgunwl (topic: 0)
# order https co nurgxema logo graphicdesigner logodesign logodesinger icon minimalist abstract https co ypmogqis (topic: 0)
# pattyhajdu navdeepsbains one safe covid everyone safe commit ensure https co awcjoekvc (topic: 0)
# let protect covid real numbers climbing fast continent let n https co bymsfxltrw (topic: 0)
# nagaland police covid awareness city tower junction dimapur covid keepsocialdistance https co wovfmqhueo (topic: 0)
# second wave covid flanders back homework https co swimzacmn (topic: 0)
# first comprehensive review wash amp covid analysis key ways wash help reduce transmission https co ecsfdmob (topic: 0)
# holy water times covid https co yazyxl (topic: 0)
# kolar need blood type b positive jalappa hospital blood component need plasma b covid recove https co xtgxulcz (topic: 11)
# munitions response team bosniaandherzegovina modified ops adopted masks disinfectants sanitizers https co lmbkxlwwq (topic: 0)
# imagine people profiting human suffering covid studying maps make https co nelsmgjuh (topic: 0)
# tncoronaupdate tn crosses lakh mark ppp recovered far covid positive today total https co qdjkpccqv (topic: 18)
# actor vishalkofficial father mr g k reddy tested positive covid days back vishal https co vlonrlwy (topic: 2)
# update total covid cases recoveries deaths reported countries africa see total numb https co eqcjehwri (topic: 18)
# unionwill megawedgy jjhorgan regarding community outbreak covid haida gwaii cases one recover https co rjzuyqy (topic: 0)
# nicolekowalski chrisdameanor feeling little anxious covid seems detracted everyone https co amhdxamlg (topic: 0)
# jfoster bbclaurak well borisjohnson might understood missed cobra meeting five https co mqpagcygn (topic: 0)
# released two new covid podcast episodes week technology platforms used conduct telehealth visits c https co gveyvczk (topic: 0)
# playyourpart fight covid one us make difference containing spread lets https co frzlgrsqf (topic: 0)
# britain understand covid months plenty countries understand took effective https co kvcaqskz (topic: 0)
# volume back please covid https co dpnbvhx (topic: 0)
# delhi reports covid positive cases deaths saturday death toll rises reports ani quot https co jxsvpwmrqs (topic: 18)
# tamilnadu covid th july tn highest spike total cases chennai https co xzguzcgr (topic: 6)
# nytimes reporting yesterday people died covid usa k new cases reported serio https co sfwpvfeb (topic: 0)
# crazy world come americans fight get covid (topic: 0)
# miss isopropyl alcohol much ethanol hand sanitizer smells like poured tequila hands covid (topic: 0)
# due covid aka coronavirus ill sending first people like amp retweet cas https co mkuusgbdk (topic: 0)
# video stitches https co tadfgqkj obesity زواج_راكان_الحربي carryminati myvsbutch https co fszntuvdg (topic: 0)
# local government sales tax revenue dropped percent year year second quarter thanks covid shutdo https co odkylzrv (topic: 0)
# check angel beautiful mask hair bow designs https co bpmptrsm etsy epiconetsy masksforsale https co fglzjmyq (topic: 0)
# thread drzoehyde based international research evidence updated thread children covid sum https co axwvotp (topic: 0)
# covid shrink power sector growth take discoms back pre uday era https co dpzpnluuv industry https co zifopdwu (topic: 0)
# saturdayvibes current situation calls awareness less stress facilitate families https co qwdbzp (topic: 0)
# economic measures governments taking respond covid key actions taken countries listed https co fxazwfalw (topic: 0)
# time see spike covid cases isvery hard reverse without drastic lockdown time https co asakjh (topic: 0)
# realdonaldtrump whitehouse see political games covid achieved shameful https co jxvuzuqwfc (topic: 0)
# hi long time see preparation us reopening homework clean https co gjeewuy (topic: 0)
# rakesh sharma best business coach india website https co oglxcgg salescoach businesscoach salesforce https co gkippljmx (topic: 0)
# nstworld nationaldayrally ndr year due safe distancing requirements result https co xjmzjypcrn (topic: 0)
# women lawyers write amitshah seeking lakh loan per financially drained lawyer covid coronavirus https co jejvtecjen (topic: 0)
# literally using head make decisions safety covid government creating conf https co kjieybty (topic: 0)
# ok angry cannot believe stupidity covid virus kills many must https co knbiyfptxb (topic: 0)
# durbanjuly weekend pity year facing covid go person https co kxxynv (topic: 0)
# let give try alreadyvideo covid hurricanehanna https co hchuafnhy (topic: 0)
# tamilnadu covid th july tn highest spike total cases chennai https co bfybahgbi (topic: 6)
# playyourpart fight covid inthistogether cavan ladies footballer aishli https co jtumdqtl (topic: 0)
# egyptians got shit covid https co kllzojaxo (topic: 0)
# voices belt road covid rap song alerts needed precautions returning work beltandroad https co onmfudmc (topic: 0)
# pr vishalkofficial father mr g k reddy tested positive covid days back vishal https co csxeqiwtig (topic: 2)
# area hit hanna covid hotspot hurricane harvey work ongoing still (topic: 0)
# u population infected covid covid trumpvirus maskitorcasket (topic: 0)
# latest foxnews covid keeps wish children waiting waltdisneyworld opens gktwvillage unable b https co jxcxwifftb (topic: 0)
# coronavirus covid disproportionately affecting communities color especially hispanic latinx ones ho https co gvrcku (topic: 0)
# highest ever number new cases yesterday coronavirus covid stayathome https co oovqrvmviy (topic: 0)
# bubbaprog school employees exposed covid manatee county schools summer https co gxiybay (topic: 0)
# benjamesphotos italy benpc lockdownphotochallenge covid https co jydbhbmc (topic: 0)
# cm madhya pradesh tested positive covid scindia also tested covid (topic: 5)
# bihar witnesses biggest single day spike new covid cases https co ztpksalet https co spkztw (topic: 18)
# lunch amsterdam away mass tourists invaded quickly covid pandemic travel https co dbcpwaao (topic: 0)
# captured snapshot amazing vcse response covid pandemic salford want say thank https co kpumajq (topic: 0)
# wells fargo tightens purse strings ride coronavirus pandemic read https co cmzwrrnk cdc https co tjixxlyvhq (topic: 0)
# think piece gender climate change context covid https co bjeswtg parimitaenergy https co cvgpyrnk (topic: 0)
# leicestershire residents develop covid symptoms even mild ones book test immediately https co nmzsjorjp (topic: 0)
# actor vishalkofficial father mr gk reddy tested positive covid couple weeks ago vishal f https co kkmbmciq (topic: 5)
# global fatalities chart last hours covid bolsonaro trump modi https co dbhpxee (topic: 0)
# drown falling river staying submerged facts saturdaymotivation truth https co cluvqktuk (topic: 0)
# badbitchinaz pay republicans leave america voteblue voteforbiden votebluetoendthisnightmare https co bgrmuetws (topic: 0)
# vietnam high level preparedness prevent covid spread deputy pm vietnam covid coronavirus ncov https co hhjrzkezl (topic: 0)
# provided north devon tourist attraction digital twowayradio solution even covid struck w https co klwjhahlkq (topic: 0)
# everyone spread covid another study accurate https co hocazyq (topic: 1)
# today day thebigspend buy local amp support covid rebuilding process shop local small busi https co xxcpttzqg (topic: 0)
# traveltuesday covid excellent data charts map cv progressing societies also https co tswuuwfswy (topic: 6)
# new positive covid cases reported andhrapradesh last hours apfightscorona stayhome https co mkputmvtyz (topic: 18)
# two quick estimates arizona post apex recovery rate avg peak covid confirmed cases https co tsibpsqjq (topic: 6)
# ar state sen jason rapert preached mask free church covid https co jrcqicihc sorry https co advdycpi (topic: 0)
# want cheat waec carrying bbnajia covid tachadancechallange saynotonipostfee https co setgtapny (topic: 0)
# kerala private hospitals covid treatment rates general ward hdu icu icu ventilator https co nwgixxauj (topic: 0)
# bignews rajasthan governor kalraj mishra appeals covid recovered patients donate plasma says https co onsdhddayg (topic: 11)
# friendly weekend reminder covid go away got bored wearamask covid covid https co xjoivuze (topic: 0)
# photos uae hospital launches support group covid patients https co wlnfgghsql (topic: 0)
# intuitive yes learning covid every day amp listening science https co ajwhoiu (topic: 0)
# alhamdulillah coronavirus deaths reported hours qatar qatar covid coronavirus https co pafpdtx (topic: 18)
# virtual chro paneldiscussion imagining workplaces amid covid july register https co oqhxqzdi (topic: 6)
# people working shops supposed wear face covering covid england (topic: 0)
# delta flight departing detroit turn around guests refuse wear masks airlines coronavirus https co vfyqafrb (topic: 8)
# covid positive cases patients recovered discharged migrated deaths delhi today https co qfqycjcmd (topic: 18)
# dying covid dying covid huge difference fakenews democrats usi https co jyzzef (topic: 0)
# airlines design covid recovery plans human centered mindset likely best position th https co aafvuqvwv (topic: 0)
# deeply saddened untimely demise constable krishna kanta burman due covid posted hastings https co uojrl (topic: 0)
# maharashtra government cuts syllabus students class view covid pandemic says school e https co hpuumv (topic: 0)
# jaipur rajasthan government today started plasmabank sawai man singh hospital jaipur treatment https co jgeya (topic: 0)
# rutland supporting covid testing https co svtrfts (topic: 0)
# want understand improving quality represents soap water wash hands covid https co enzxpeexij (topic: 0)
# thedailyedge seanhannity foxnews spread lies hate sexual violence murder covid foxnews (topic: 1)
# covid new york retail https co auvgnyfe (topic: 0)
# covid delhi reported new cases deaths today taking total number cases death tally (topic: 18)
# tech leaders help position organization techstrategy way aligns shifting investment https co aidjsqvva (topic: 0)
# danang covid patient health gets worse quickly prompting doctors use ecmo amp filter blood https co cgtux (topic: 0)
# colleaguesforlife helped deloittealumni karen seminara patton co found organization help med https co xcbgvesyy (topic: 0)
# successful openingday grandslam walkoff matt_olson anyone else thinking six feet ce https co xwjfnifq (topic: 0)
# brazil bilsonaro tested positive covid says latest test result negative (topic: 0)
# affected brief covid lock take time think animals permanent https co meumruau (topic: 0)
# stop foggy glasses hack covid facecoverings maskproblems facemask hack maskhack maskmoaners https co ijurqvubhl (topic: 0)
# symptom duration risk factors delayed return usual health among outpatients covid multistat https co wnulbdok (topic: 0)
# covid religion st century jews fighting st century christian evangelicals (topic: 0)
# pr vishalkofficial father mr g k reddy tested positive covid days back vishal https co wvfodzswx (topic: 2)
# benjamesphotos pink benpc lockdownphotochallenge covid saturdaymorning flowers https co dlggosbpjq (topic: 0)
# national state impact covid elder population societal loss wisdom history https co gaifwidcb (topic: 0)
# covid andhrapradesh new cases deaths samples tested discharged e https co lklzorkr (topic: 6)
# alert eye opener rep john lewis remembered global pandemic news coronavirus covid protests https co dcpsebx (topic: 3)
# venrap radio playing venrap radio stay safe covid love download app listen https co eqqgbjme (topic: 0)
# shall come victory minds fightagainstcorona retail outlets across india adher https co qwnpucxbxj (topic: 0)
# absolutely standing rd position worldwide lakh covid cas https co qxwojlgcaz (topic: 0)
# coronavirus update nearly countries report record single day increases infections us records https co pbhpwgfdu (topic: 0)
# undercover inspectors deployed abudhabided make sure anti covid measures foll https co lndygbfxit (topic: 0)
# hospital cleaners porters amp catering staff unsung covid heroes tell issworld pay fair wage https co tsrgmgqlx (topic: 0)
# manufacturing production activity begins echo trends indicating industry normalization https co zrjogkzqn (topic: 0)
# economies participating asia pacific economic cooperation apec reaffirmed prioritization economic https co fxiwpmudnl (topic: 0)
# apec reaffirms covid economic recovery priorities movement essential goods https co swrelfss (topic: 0)
# july covid trend report dallas tx dfw covid cases hospitalizations deaths day average https co rztocanh (topic: 6)
# cautious optimism arizona may plateauing covid potential good news https co jgophk (topic: 0)
# want covid test much easier get wealthier whiter neighborhoods testingwhileblack https co vcddrlhfes (topic: 0)
# truth covid around somewhere coronavirus update saturdaymorning saturdayvibes https co hilerfhc (topic: 0)
# coronavirusspain covid warning spain could death trap second spike catalonia barcelona https co aufxdns (topic: 0)
# three cs term heard good advice goodadvice covid https co yksvjbilkp (topic: 0)
# delhi covid positive cases patients recovered discharged migrated deaths today https co tybhavgo (topic: 18)
# great abcrobert yesterday abcgmw socialdistancing bbq covid covid https co xsicvtsga (topic: 0)
# yes wakeup covid fake plandemic exosomes virustheory g real virus saynotobillgates https co fjwhahiv (topic: 0)
# great tips friends samhsagov covid inthistogether https co btsihvngb (topic: 0)
# football jersey count first md nfl opting care others medbikini covid chiefs https co zjtqqghq (topic: 0)
# pandemic could push n carolina families home school miami herald https co ohfjumb homeschooling covid coronavirus nc (topic: 0)
# government tabla player countries pandemic covid covid https co wwoifxl (topic: 0)
# since everything changing covid redsox start playing version sweet caroline games th https co lqqdwhc (topic: 0)
# use many sources covid guidance use cdc things fact check sour https co ipyuezbzh (topic: 0)
# brilliant see people awake accepting covid mainstream narrative (topic: 0)
# alreadyvideo rihannaxtiwa obasekiflagsofftoday covid tachadancechallange fraudbyquodjoe bbnaijia https co ccusuoemsd (topic: 0)
# feeling good sounds like soul song covid https co efpsibl (topic: 0)
# ekiti covid update july forty two active cases covid ekiti state https co qdxgafumd (topic: 6)
# still travel credit covid stimulus (topic: 0)
# thanks govofco stressing personal responsibility facecoveringmandate limiting spread covid https co ybajfunyw (topic: 1)
# ukraine president renewed invitation abdel fattah al sisi visit ukraine covid ab https co qnizwjfy (topic: 0)
# goodjobcop saturdaymotivation dcp hari kiran chennaipolice_ helped radhe amma sanitary worker get j https co lhazcxhsx (topic: 0)
# sad reality hundreds cars line drive thru food drive florida https co pqouluznu covid (topic: 0)
# awesomeness know bbnaijia rihannaxtiwa alreadyvideo covid https co gujptold (topic: 0)
# drive covid testing hours kinsmen changing monday https co stxgznlis https co fovqibuq (topic: 0)
# even covid vaccine face coverings stay feels like massive shift towards https co kkbqvtzt (topic: 0)
# liammcbaen say one loneliest number anyway wearamask realmenwearmasks toughguyswearmasks https co speaaylxj (topic: 0)
# hate covid coz made lose love life pain unbearable yooh hope heal one day https co siolgvqeo (topic: 0)
# expert explains wrong talk second wave covid https co nfhaihdvl covid (topic: 0)
# mick_inla yes hoody trayvonmartin mask covid far followers real friends l https co ohpsszt (topic: 0)
# help slow spread covid identify risk cases sooner self reporting symptoms daily even https co ucckbzp (topic: 1)
# covid testing programme cyprus customer service employees ongoing source https co zqorzcbmx (topic: 0)
# late baby sister left behind three sons eldest far right diagnosed covid https co bncpowcmi (topic: 0)
# covidupdates covid cases last hours till apfightscorona covidpandemic https co wefgvienyt (topic: 12)
# bbcaq oh yes sure perfectly happy self certification distress wearingamask wearamask viralload covid (topic: 13)
# another exgop er amazing took pandemic regret choice hey better late never https co glfmzceco (topic: 0)
# took two weeks limited population one members test positive covid followed https co objlmlyd (topic: 0)
# countries reopeningschools well guess countries raging hotbed covid right https co qtciwcttd (topic: 0)
# rough clubs shut newyork since covid hit wanted find suggestions online https co srpxkmwm (topic: 0)
# france require spot covid tests travellers coming countries united states brazil alg https co naugfdlxus (topic: 0)
# bitcoinbehemoth nope covid coronavirus cantstopthetruth https co kjkybfwvm (topic: 0)
# ckkirsch comments andrewcuomo mishandling senior covid patients politically motivated ar https co dorcmi (topic: 0)
# since go coffee shop covid imagine outdoor space early morning reading https co yksjlwyw (topic: 0)
# today croatia new cases covid new death active cases bnodesk https co rojpewplp (topic: 18)
# bhadeliamd ok little disturbing us get covid data korea like youth study https co llqfphaxd (topic: 0)
# covid luring canadians stockmarket https co epmbxxx https co wezuclodr (topic: 0)
# andhrapradesh reports new covid cases saturday tally goes death toll increase https co rcgesysmuh (topic: 18)
# berniesanders guy gets wearamask realmenwearmasks toughguyswearmasks maskssavelives https co zvfpskd (topic: 0)
# joshmatlow ontario government done close nothing possible people pandemic https co rggecshlf (topic: 0)
# denisear tomcottonar trump gop amp betsydevosed unfit office plan return school church wo https co rwzbtcjd (topic: 0)
# latest updates covid qatar covid https co ilukoxgti (topic: 0)
# hope everyone watching news report death everyone dying covid need reeva https co ivcsgzsutb (topic: 0)
# enjoy covid telecommuting remoteteaching remotelearning barbados beachoffice https co gsvgtmlft (topic: 0)
# county health department aahealth closes dutch farmers market annapolis due covid related violations https co rocukc (topic: 0)
# covid climatechange intersect many ways right hurricanehanna expected bring severe flood https co ciyielam (topic: 0)
# covid recovery home requires space prevent infection others living roof https co bavfyid (topic: 0)
# southcarolina healthcare leaders say hospitals filling covid cases continue climb coronavirus https co snwssrutbv (topic: 0)
# andrewmlangeni memorial myanc urges mourners adhere covid regulations motso_modise https co ivdevzeqf (topic: 0)
# new covid cases reported delhi past hours taking total number cases https co sfawwzzzi (topic: 18)
# barcelona legend xavi hernandez tested positive covid head coach qatar al sadd said soc https co hqmloyn (topic: 5)
# active covid cases assam india increased last hours per hour data mohfw goi (topic: 12)
# ray_ban every business dealing covid far worst experience keeping w https co twdiuhl (topic: 0)
# safely restart non emergent essentialsurgery covid pandemic join edt https co bhaegiuwn (topic: 0)
# got brain tickled covid test told check questdx website results l https co jwjjxgdt (topic: 0)
# covid lucknow cmo dr narendra agarwal replaced dr rajendra kr singh immediate effect lucknow https co afqidbtthd (topic: 0)
# love wicked rihannaxtiwa alreadyvideo obasekiflagsofftoday odikwabyblaqdee covid https co bvajjwkxl (topic: 0)
# since andaman tourism opening amp income asked police tell crime could commit amp j https co nmakbidw (topic: 0)
# open access gp essay covid mobile phone apps fail vulnerable covid tracing pandemic tech https co scefuog (topic: 0)
# ggomegafan nikolovscience still thing distinct covid_ covid (topic: 0)
# countries reported disruptions children immunizations covid decades progress https co vrjtkhvnr (topic: 0)
# running balance get smart number recharge online stayhome care smart covid https co hpmnyo (topic: 0)
# online retail sector busier ever since outbreak covid easy steps improving https co xjztyzrgf (topic: 0)
# really dont wanna miss bbnaijia alreadyvideo rihannaxtiwa obasekiflagsofftoday covid https co hpqthl (topic: 0)
# speed spread coronavirus unprecedented due subtle black energy negative ener https co fsdfdzws (topic: 0)
# retail stores really limiting hours deep cleaning limit wages covid (topic: 12)
# andhrapradesh covid arogyaandhra andhra pradesh new positive cases new discharges ne https co lngbekfj (topic: 18)
# safety first world brands offer customer experiences ensuring well convenience set themsel https co vyvwjnzr (topic: 0)
# weekend leadership reading https co ouveoms workplace covid future https co ghlrzqbw (topic: 0)
# uae started inviting volunteers world first phase iii covid vaccine clinical trials https co djcruordof (topic: 0)
# covid business decision using medical career make decision nfl https co vznttpqs (topic: 0)
# covid causes smell loss neuroscience news https co oggihyctd (topic: 0)
# amazing nedbanksport using officialpsl partnership covid period provide knowledge https co fjppms (topic: 0)
# covid andhrapradesh new cases deaths samples tested discharged e https co pyefgwkcn (topic: 6)
# help slow spread covid identify risk cases sooner self reporting symptoms daily even https co xpfoqwcq (topic: 1)
# australian open smaller crowds player bio security ausopen australianopen coronavirus covid https co pzojvjddq (topic: 0)
# obese excessively overweight increases risk severe illness death novel coronavirus https co cqovyywzb (topic: 0)
# animsxavi much strength idolo covid https co okzmoevfpp (topic: 0)
# guys party covid covid covid isthisserious gambia covid salieutaal farageloubna https co ngyninlwyi (topic: 0)
# okay visit granny nursing home even doors visit covid https co ykbnotqdm (topic: 0)
# get covid unlikely experts say https co awlwcguei problem https co bxapmgh (topic: 0)
# stayingupszn ask covid katiehopkins lufc (topic: 0)
# bill_maxwell_ yes vote member gop six months later nothing covid votebluetoendthisnightmare (topic: 0)
# pawankalyan resuming movie shootings latest interview covid janasena powerstar vakeelsaab https co xzoaujwzp (topic: 0)
# realdonaldtrump trumpdeathtollk million cases covid millions unemployed trumpviruscatastrophe https co aajwde (topic: 14)
# help slow spread covid identify risk cases sooner self reporting symptoms daily even https co igcmhxaft (topic: 1)
# know one could foreseen covid uk would far better position lo https co epmmxxmh (topic: 0)
# yesterday leftytossers attacking boris pointing obesity negative effect victims ar https co puaitkdb (topic: 0)
# wit econs meltdown bcos covid wit battered state purchasing power citizens wt rising pove https co piqpiuy (topic: 18)
# yestwrday friend brother died zimbabwe called ambulance pm came pm covid (topic: 0)
# ahmedabadrain finally looks like rainy season started may brings hike covid infec https co aceceherrk (topic: 0)
# children affected infected dying florida covid reopensafely reopeningschools health covid https co xzpmnez (topic: 0)
# catalonia spain reports new coronavirus cases covid (topic: 6)
# alert pregnant women risk death kenya covid curfew global pandemic news coronavirus covid https co miklfxctvj (topic: 0)
# check us spotify well https co vxkbfatfj gospelhouse godgotthis https co oeiuqvcgr (topic: 0)
# could double covid vaccine delivery mechanism borisjohnson matthancock pritipatel https co hmekvlf (topic: 0)
# help slow spread covid identify risk cases sooner self reporting symptoms daily even https co ksyvttdgqo (topic: 1)
# sign alert stop deadly mass killing animals university labs due covid https co tzaxaees (topic: 0)
# latest islam islamism https co gxwuocr berkleyforum covid (topic: 0)
# hope usa trump vilifying usps amp amazon republicans premium stock catering postmaster w https co wznvskwko (topic: 0)
# coronavirus andorra total confirmed deaths covid (topic: 6)
# wear face cover pay fine new laws imposed london covid london lol chose cover https co aoqmqvln (topic: 0)
# covidupdates ap records many new cases last hours taking tally deaths wer https co donjrcate (topic: 0)
# statistics pic gives info assam performing better odisha fight covid https co rdrtsdfwyf (topic: 0)
# masks social distancing crowded falls attractions cbc news https co tfwjehdlhi covid (topic: 0)
# realdonaldtrump remember worstpresidentinhistory trumpdeathtollk million cases covid millions u https co tvdxasnj (topic: 14)
# cdc changes covid guidance long people need isolated https co lqeqkbbqan via nbcnews covid theyhavenoidea (topic: 0)
# plea mask wearers read many nomasks want blindly follow govt edicts https co uqwjzypqj (topic: 0)
# mp cm shivrajsinghchouhan tested positive covid news bcoz many ministers wel https co ciaqsqxq (topic: 0)
# sending science deniers home fellow magats bluewave covid https co bkmbdjcldk (topic: 0)
# andhrapradesh andhra pradesh registered single day spike covid positive cases amp deaths last https co xkrjynf (topic: 0)
# thing lightskinned every bruise body seen mars plus fact https co mwqnmipann (topic: 0)
# actor vishalkofficial father mr g k reddy tested positive covid days back vishal https co yxdpgtkw (topic: 2)
# pawankalyan resuming movie shootings latest interview covid janasena powerstar vakeelsaab https co bpalifxaf (topic: 0)
# another wwe employee contracted covid via pwcdeez wwe wrestlemania covid coronavirus https co sxcuhna (topic: 0)
# thats got productive quarantine hard assignments quizzes productive covid https co bmeqhtphm (topic: 0)
# covid restriction extended kupwara till august coronavirusupdate fightagainstcovid pandamic https co xepclbrd (topic: 0)
# big thank team cenit college nass ongoing support adr exams due covid https co sjmuyidnr (topic: 0)
# new personal view need sustainable biobanking networks covid diseases epidemic potential https co jmykcizoju (topic: 0)
# covid worsened already dire opioid crisis fewer social supports people battling addictions mu https co windzkoyn (topic: 0)
# passengers cheer karen kicked flight refusing wear mask airlines coronavirus covid mask https co vimrsfaub (topic: 8)
# oh fvck sake cnn sarahcwestwood stop bs trump changed tone foxnews cnn weeke https co dvbgccqf (topic: 0)
# nycaudubon audubon saturdaymorning saturdayvibes covid saturdaythoughts saturdaymotivation free shipping https co vutthfsypo (topic: 0)
# orangebaboon wants make sure k dead covid end july dea https co covtyforrl (topic: 2)
# together one covid economicrecovery https co dwablnfpjr (topic: 0)
# progressed point joking covid good could get sort https co akdfttpsfy (topic: 0)
# schools reopen spread covid biblical scale (topic: 1)
# coimbatore district administration announcing complete lockdown pm saturday till monday h https co tnlkwgm (topic: 0)
# realdonaldtrump trumpdeathtollk million cases covid millions unemployed trumppandemicfailure https co fbcbtoxkqc (topic: 14)
# cheap virus killing spray costs pennies could end britain coronavirus covid nightmare https co lsvcyqiwes (topic: 0)
# hurricane may hit area major covid spread amp full hospitals need https co nlfpyvevz https co dulqthatyt (topic: 0)
# day freepalestine palestinians still danger covid palestinianslivesmatter endapartheidnow https co chdhekuoge (topic: 0)
# alert right wing people least likely wear face masks global pandemic news coronavirus covid protests https co aexqvuhy (topic: 0)
# covid historical nightmare https co xftqpupnwp (topic: 0)
# brazil bilsonaro tested positive covid says latest test result negative https co mzrdgdgu (topic: 0)
# delhi covid update july new cases total deaths total discharged total https co sfrposblt (topic: 6)
# 新冠肺炎 strange new beginning 新型コロナウイルス covid stayhome washyourhands physicaldistancing https co wrwtoiml (topic: 0)
# please send prayers towards family getting tested covid covid (topic: 0)
# thinking clip addressing covid head went heard tcm would love https co wnweofzmt (topic: 0)
# jib madagascar covid herbal medicine cure cough health minister osagie ehanire https co uekuorjme (topic: 0)
# esey_bee hey esey thread soychicka compiled read https co ycptmgagy covid (topic: 0)
# covid clearly brought two types decision makers respond crisis using common sense awarene https co aonvnfqv (topic: 0)
# long look good carl vernon https co zislup covid moneymatters insanity (topic: 0)
# covid pandemic live responsible people protect one life save many life xeshamusiq (topic: 0)
# icu puri district headquarters hospital sealed patient tests positive covid odisha https co gvhnbyeg (topic: 0)
# toywillyk mz_saba nipostngn covid removed fold eyes (topic: 0)
# icicibank_care please soon unblocked debit card danger go bank covid pandemic icicibank (topic: 0)
# stay safe keep washing hands stayathomeandstaysafe stayhomezim covid chat dailynewszim https co rifelznim (topic: 0)
# due covid aka coronavirus sending first people like amp retweet casha https co jaamlgoxa (topic: 0)
# highest covid total deaths india maharashtra cases followed delhi information source goi (topic: 18)
# mumbai bmc seals navjivan co op housing society following spike covid cases https co qptokfxn mumbai https co ticgrj (topic: 18)
# love local businesses come creative ways stay open covid supportsmallbusinesses https co fyqcwrghg (topic: 0)
# situations covid spread people animals sick avoid contact pet kee https co qvtlbgora (topic: 0)
# finally cdc crawling way acknowledge long term impacts covid small step following w patie https co euycpjzo (topic: 0)
# resources help fire departments identify report counterfeit ppe https co kdksiidft covid (topic: 1)
# fear effective strategy knowthefacts protect children care use https co crjjxjxqcs (topic: 0)
# nstnation proved costly night people slapped rm compound aft https co rquzatgn (topic: 0)
# farmer forced use daughters instead oxen pull plough fields due financial crisis du https co evpfdesq (topic: 0)
# concentrate covid lost friends suicide amp cancer important message check th https co ibexhbvb (topic: 0)
# actor vishalkofficial father mr g k reddy tested positive covid days back vishal https co dkswxswcmu (topic: 2)
# hahahahha morning humor russia russia russia schiff russiancollusion interference covid potus https co tkboenxi (topic: 0)
# city_ekurhuleni covid pandemic live responsible people protect one life save many life (topic: 0)
# covid positive cases patients recovered discharged migrated deaths delhi today https co nzyndmhmhj (topic: 18)
# see lot articles granny grandpa dying covid newsworthy art https co otkcxrunl (topic: 0)
# coronavirusupdate coronaviruspandemic new coronavirus cases reduction active cases recov https co abdivjxrk (topic: 6)
# mistake florida child covid rate raises question florida numbers trusted https co hfdndlms (topic: 0)
# covid political issue wonder stephen miller thinking today https co geelikrrtr (topic: 0)
# checkout video ruth sacrifice https co ykiknknyb obesity carryminati myvsbutch https co fleude (topic: 0)
# covid pandemic identified vulnerabilities business address potential disruption https co pxvkxufha (topic: 0)
# year united states failed controlling covid failed keeping cities peacefull donald https co bikergtno (topic: 0)
# anyone still thinks teachers concerned covid want go back school sadly misinformed (topic: 0)
# making first interactive dashboard oraclecloud teams final data preparation https co pessaiid (topic: 0)
# vadodara covid tally cases samples east west north south rural discha https co semkfcump (topic: 18)
# vishalkofficial amp father mr g k reddy tested positive coronavirus days back vishal f https co sgvrpnmnz (topic: 2)
# davemacladd proroguing parliament closed gov dec ignored coviduk jan prioritised torybrexit holid https co oltntupqa (topic: 0)
# healthworkers infected covid dr talisuna need member states amp partner https co cubnlfzwmb (topic: 0)
# first theatreinafrica webinar went well recording soon available sharing first let https co kagvfbouct (topic: 0)
# thankfully epidemiologist working w covid daily basis amp recognized symptoms right away also https co ebdctvxd (topic: 0)
# really happening neighboring pakistan almost daily deaths june number daily https co ysxmalho (topic: 18)
# leaving covid https co ofpbtfabv (topic: 0)
# brucewilson goodquestion montlick thoughts covid (topic: 0)
# please follow mickclifford kbf true freedom fighter scamdemic nomasks covid https co egdtiqcbc (topic: 0)
# warning health hazard borisvoteofnoconfidence borishasfaileduk secondpeak secondwave coronavirusuk covid https co xrebqylw (topic: 0)
# help slow spread covid identify risk cases sooner self reporting symptoms daily even https co uxmexueky (topic: 1)
# second wave covid uk government blame (topic: 0)
# help slow spread covid identify risk cases sooner self reporting symptoms daily even https co pjbqqbdq (topic: 1)
# alignable network local businesses connect us alignable callthemfirst selectrestoration https co zmfsprfbot (topic: 0)
# usa people reported hospitalized friday covid (topic: 0)
# alert federal agents use tear gas clear portland protest global pandemic news coronavirus covid https co oojpmfo (topic: 3)
# guernsey daily coronavirus covid report coronavirus guernsey corona covid https co mcrzxnvtj (topic: 0)
# brazil president bolsonaro tests negative covid https co bmschaojk (topic: 5)
# madhyapradeshcm shivrajsinghchouhan tests positive covid cm announced twitter ha https co hurbkhv (topic: 5)
# dogs could sniff covid saliva people healthy infected https co yctvwpv (topic: 0)
# delivered impending evictions catherine constituent pittsburgh pa sentoomey pa papol https co njgmbaam (topic: 0)
# texas hospital overwhelmed coronavirus may send patients home die cnn covid https co nzzrylczhx (topic: 0)
# recall horror impact us covid covidusa https co nagpvcv (topic: 0)
# day new cases covid florida growth new cases days texas growth new cases https co lczrime (topic: 0)
# add ngurah rai international airport list places bali get covid rapid test tes https co bvlfucsgx (topic: 0)
# new covid preprint covid data driven mean field type game perspective https co devlhehga (topic: 12)
# realcarlvernon properly stated ladies gentlemen live clown planet ta ta covid plandemia scam (topic: 0)
# chief minister uddhav thackeray today inaugurated covid care centre testing lab dombivli via video c https co xhmgymoqmb (topic: 19)
# due covid aka coronavirus ill sending first people like amp retweet cas https co olwkkufcrz (topic: 0)
# new covid preprint country distancing reveals effectiveness travel restrictions covid https co vxmcaejs (topic: 12)
# covid spurred investments digitaltransformation amp india cusp digital revolution https co ltaohzpmx (topic: 0)
# according data pakistan successfully flattened curve covid coronavirus patients hav https co ajvacyxoe (topic: 6)
# new covid preprint anxiety perceived risk covid outbreak https co ergzblmgp (topic: 0)
# bangladesh records new covid deaths https co ysthawmpn bangladesh covid (topic: 18)
# new study highlights impact coronavirus pandemic families mental health nbc chicago covid https co tcsobrz (topic: 0)
# new covid preprint analysis mortality ontario using cremation data rise cremations covi https co drwxijrn (topic: 12)
# covid pakistani emirati hospital rawalpindi treats virus patients full care https co daynzbipos (topic: 0)
# day ahead launching voter registration jammuandkashmir online referendum campaign see https co jalksnsps (topic: 0)
# talking covid vaccines smerconish cnn est morning https co ghifinda (topic: 0)
# canadian driver stop locations get tested free covid weareinthistogether trucking https co vqgkplrccr (topic: 0)
# new covid preprint epidemiological cohort study finds association covid guillain barre sy https co vfibnzl (topic: 12)
# yippeekiyay_dk excellent analysis failure setu_app perfect example shivrajsinghchouhan late https co dtptym (topic: 0)
# survey first week covid outbreak italy suggest people highly resilient especiall https co bqmjftdc (topic: 0)
# updated covid preprint role hydroxychloroquine age covid periodic systematic review https co lymfsphh (topic: 12)
# new covid preprint infectivity susceptibility risk factors associated sars cov transmission https co fxlxqemyj (topic: 0)
# coronavirus report hill steve clemons interviews coronavirus covid frontlineworkers https co hvdonueza (topic: 0)
# last months used running amp singing ways reducing anxiety due covid pandemic https co hwzrvfysw (topic: 0)
# america problem covid shocked marxistblm brought america knees sad https co xuqlbozh (topic: 0)
# love borders covid https co eihvila (topic: 0)
# updated covid preprint impact hypertension progression prognosis patients covid retrosp https co nijlieqgz (topic: 0)
# new covid mutation helps outbreaks spread quicker expert covid coronavirusupdates https co vijbnbr (topic: 0)
# today covid testing pm burke high school https co gmwltftu (topic: 0)
# americans dead coronavirus hey pawpatrol canceled shitting jesus https co pohwuv (topic: 0)
# rajasthan government today started plasma bank sawai man singh hospital jaipur treatment covid p https co spkdmtpy (topic: 0)
# topgunmaverick aquietplace three starwars films postponed due covid pandemic covid https co kevnfdzps (topic: 0)
# covid stressing ways sleep better coronavirus covid lifestyle healthtips https co jkrwlrlsrw (topic: 0)
# new covid preprint mathematical modelling dynamics containment covid ukraine https co mvyxkgxeu (topic: 12)
# join fhi amp africacdc july webinar deploy covid response preserving https co sqyeklhpz (topic: 0)
# america shithole country trump racism covid https co ovuadjd (topic: 0)
# administrators uc berkeley announced fall semester begin fully remote instruction covid https co klpguamdw (topic: 0)
# chatttylady lbilderberg mailonline covid coup amp either blackmailed held hostage https co sicjlkaxl (topic: 0)
# covid cases confirmed artsakh https co twjngzxnlh (topic: 18)
# new covid preprint sars cov serosurvey health care workers veneto region https co zizmbhvmqx (topic: 0)
# story saying good dead covid south africa hard feel anguish left b https co dpyvhudfgf (topic: 0)
# durbanjuly mask butterfly symbolize hope dark time covid stayconnected vdj https co dyzvmozw (topic: 0)
# updated covid preprint prevalence igg igm antibodies sars cov among clinic staff patients https co vjqhmzop (topic: 0)
# gt smi offering protective face shields fight covid connect us phone https co hdocihmrz (topic: 0)
# new covid preprint decreased incidence virus transmission capacity severity covid altitude th https co pfiflwhv (topic: 0)
# realdonaldtrump brandonstraka foxandfriends petehegseth golf game americans dying https co azagkhiluz (topic: 0)
# cope covid https co aaxqkrnjen via youtube covid pandemic mentalhealthmatters (topic: 0)
# new covid preprint sentiment informed timeseries analyzing ai sitala curb spread covid houston https co jutzjvbktx (topic: 0)
# miss himss webinar fs_healtchare reenitadas share new growth opportunities connected https co hnafozikwy (topic: 0)
# international friends states around world ever thought sort covid schooling crisis https co nvkanznqo (topic: 0)
# new covid preprint concerns quality life access care productivity general population https co ilcqsuim (topic: 0)
# quimtorraipla management covid catalonia demonstrates incompetency catalan citizens https co jpgbnzqvvs (topic: 0)
# point pandemic fall dog memes covid ht lunanharry https co idozdxke (topic: 0)
# icymi youssef belhaissi tv host amp union leader morocco fired workers med tv sought better sa https co wisdisfr (topic: 0)
# colly sweetness love daddy official video african story written colly sweetness ledimo https co kaxvi (topic: 0)
# living poverty bad health long covid via adamtinson healthfdn https co iaomwe (topic: 0)
# read article training safety healthcare professionals covid posted monthly news https co yvoogpjl (topic: 0)
# new covid preprint cell type specific immune dysregulation severely ill covid patients https co jjpuknk (topic: 0)
# finally brazilian president jairbolsonaro tested negative covid test made tests positive https co mbppefxa (topic: 5)
# tesco laurarutherford getting rid contract cleaners perhaps important ever covid (topic: 0)
# strokes brain inflammation psychosis dementia like symptoms could linked covid researchers sai https co wzpmniga (topic: 0)
# pamela anderson takes ppe airport makes fashion blue gloves going st covid flight https co wfpxwcvr (topic: 0)
# new covid preprint severe covid associated elevated serum iga antiphospholipid iga antibodies https co zobvyivu (topic: 12)
# insight offer covid antibody testing nasal swab tests taking long https co hdwsynwn (topic: 0)
# new covid preprint reducing covid hospitalization risk behavior change https co wyikfhmzd (topic: 0)
# body weapon patients https co mfromkma covid coronavirus pandemic virus https co eorkppwxsg (topic: 0)
# texas hospital says man died attending covid party new york times covid covidhoax science https co ghcqdbvm (topic: 0)
# maharashtra india new covid confirmed cases reported last hours info via mohfw (topic: 12)
# half world mobilemoney users africa tech solutions help people affected covid jo https co gmqoyybk (topic: 0)
# new covid preprint comparative evaluation reverse transcription loop mediated isothermal amplification https co xqoljxx (topic: 12)
# peace better holding grudge life short music love support artist lovewhatyoudo https co jrovvvg (topic: 0)
# rajasthan governor kalraj mishra appeals recovered covid patients donate plasma plasma bank sawa https co clompzrat (topic: 11)
# one besides medical staff complaining wearing mask wearadamnmask covid coronavirus https co utqvkzwj (topic: 0)
# exactly afraid would happen another puerto rico response feds covid https co ahlcmus (topic: 0)
# new covid preprint covid vulnerability transgender women without hiv infection eastern https co hbitygwsat (topic: 12)
# r rep vern buchanan dies covid coronavirus https co qsobwd (topic: 0)
# washing hands one best ways protect covid millions people refugee c https co sxwaymj (topic: 0)
# latest update coronavirus covid uae we_are_all_responsible youareresponsible https co kgjfgs (topic: 6)
# new covid preprint development quantum dot lateral flow immunoassay strip based portable fluorescence smar https co jvudcajx (topic: 12)
# must urge canadians particularly younger adults give covid fatigue younger age groups https co psvolozp (topic: 0)
# covid change work general recruiting specifically via proactivetalent recruiting https co kwwlapiup (topic: 0)
# covid situation south indian states glance july testing statistics tamilnadu amp https co mrbjfjc (topic: 4)
# new covid preprint presence sars coronavirus sewage https co fvybyccfs (topic: 0)
# callforcode submission deadline climatechange amp covid solutions july st top call https co ozgayijojp (topic: 0)
# actor vishalkofficial father gkreddy tested positive covid days back vishal fat https co cvfzv (topic: 2)
# nicolasturgeon thesnp used covid response create baseless divisions scotland ukgovt https co mftavs (topic: 0)
# updated covid preprint virus receptor interactions glycosylated sars cov spike human ace receptor https co cqfvzqxyai (topic: 0)
# alex_verbeek help slow spread covid identify risk cases sooner self reporting symptoms da https co apfzuma (topic: 13)
# vadodara covid tally cases samples east west north south rural discha https co znnxxgepu (topic: 18)
# new covid preprint tissue specific interferon inducible expression non functional ace endogenou https co hpxhgncotq (topic: 12)
# pensmoc man get better least sense humor good coronavirus covid hoax https co dtycivuuu (topic: 0)
# srsly getting hands like covid ihaveajoke ihaveajokeon https co prqdxex (topic: 0)
# tens thousands americans infected covid daily millions face imminent eviction peaceful p https co rzmlzleou (topic: 0)
# iit kharagpur portable device test covid rs covid covidtesting covid https co lntapgdee (topic: 0)
# updated covid preprint relevance sars cov related factors ace tmprss expressions gastrointestinal https co pndxtqxkq (topic: 12)
# fashion pandemic trillion us fashion industry covid https co crynvkjbab https co ldhgvuawg (topic: 0)
# r africa map puzzle order rustenburg hartebeespoort alreadyvideo covid djsbu https co mrgilric (topic: 0)
# updated covid preprint integrin binding peptide atn novel therapy sars cov infection https co illdxbhji (topic: 12)
# life seems going circles could symptom covid covid (topic: 0)
# people businesspersons living continued stress https co rnfkaoc economy crisis debt loan grant https co seohtja (topic: 0)
# homeschoolers must set children free education automation learn whatever want learn https co iegnghgv (topic: 0)
# new covid preprint co expression mitochondrial genes ace cornea involved covid infection https co fhcymkza (topic: 12)
# rajasthan government today started plasmabank sawai man singh hospital jaipur treatment covid pa https co hcplvqdfp (topic: 0)
# inspirational life inspirational motivation covid telangana andhrapradesh india https co gwxzt (topic: 14)
# new covid cases romania new negative record soon romania might blacklisted travelling https co cchqzeeb (topic: 14)
# despite covid pandemic matrixfitnessus fitness equipment brand taiwan johnson health tech made r https co niyjgmejk (topic: 0)
# opinion covid directorgeneralofghanaeducationservice writing exams pandemic https co ulivrwt https co qpkifgay (topic: 0)
# coronavirus world map countries covid cases deaths https co xrgenskqrp (topic: 0)
# difficult positive anything friend talking covid remember https co nxuqyjruqu (topic: 5)
# proactive response strategies covid business challenges products different channel infrastr https co eqiptnqh (topic: 0)
# case need reminding handwashing wearamask socialdistancing pivotal achieving control https co bcbkbafj (topic: 0)
# family making plans weekend keep things mind covid pandemic https co pnfiyhmsa (topic: 0)
# updated covid preprint potent neutralizing antibodies directed multiple epitopes sars cov spike https co occmabei (topic: 12)
# must remember people susceptible covid long circulating everyone risk https co wjswgehmis (topic: 0)
# follow back rihannaxtiwa alreadyvideo tachadancechallange هيون_الغماس bbnaijia bbnaija https co qteczaz (topic: 0)
# actor vishalkofficial father mr g k reddy tested positive covid days back vishal https co fcvnqzwtcx (topic: 2)
# great summary evidence limitations information sarscov covid transmission schools https co xixyezwix (topic: 0)
# hong kong covid situation remains grave new cases hit record https co xjoiuvumgo https co uyqrgqxkr (topic: 14)
# ons johndmtb real covid deaths phe_uk figures (topic: 0)
# ny eye covid dying daily pleaded w america shut tweeps tx ca amp fl ca https co zkcxfgaov (topic: 0)
# coronavirus divides bellwether county wisconsin grace anymore election politics https co eajfws (topic: 0)
# ironhorse time act unite end corrupt gop regime follow back resist covid https co xsgwhdp (topic: 0)
# stigabell sebdance watch please minimise spreading wearamask covid coronavirus mask https co thcqrrm (topic: 0)
# chart showing number new cases covid cases poland plus average number daily new cases https co abxtaczg (topic: 18)
# air godhra mhz message covid dilip yadav r panchmahal broadcast today pm https co nstlfrt (topic: 0)
# covid situation companies given work remotely right else stay focused https co utsaa (topic: 0)
# love djsbu covid https co xzkoqraam (topic: 0)
# covid lessons learned past epidemics sexual reproductive health srh learn https co akzwmrld (topic: 0)
# today covid info updates goc website coronavirus disease https co pwqogtoknl covid https co bgozjbdkhe (topic: 0)
# qatar mophqatar announced today recorded new covid cases recoveries people tested https co ylliapguwi (topic: 0)
# unless gop bureaucrat like steve steve_hanke loved paid firehanke sledgehammer https co tzukuhgpmg (topic: 0)
# ...
# coronainfoch covid corona us sink https co dsofoefk (topic: 0)
# last updated gmt coronavirus covid cases deaths corona https co yjugurwb (topic: 0)
# covid pandemic left thousands moroccan women stranded spain living abject conditions https co sfnigdwrq (topic: 0)
# interesting video growing connection covid g technology paper cited video remo https co njxnnuic (topic: 0)
# better understanding populations increased risk severe covid fundamental effectiv https co mgoefgxte (topic: 13)
# saturday share happy moment loved ones blissful weekend covid https co xkbuiqap (topic: 0)
# still covid unsafe travels cooler full goodies less stops road non perisha https co ulwsqsbno (topic: 0)
# wanna relass taken kiaruf somebody son coman spoil biko bbnaija https co rjnntnzwa (topic: 0)
# etrealty construction workers yet receive one time relief karnataka constructionworkers covid https co puilygwme (topic: 0)
# covid beaten would aboard flight af morning headed two weeks vacation ar https co iiqargxxhk (topic: 0)
# social distancing quarantine flatten curve workfromhome photography gettyimages gettyimagescreative https co pvcslwrtqu (topic: 0)
# join us help shape delivery travel health services covid beyond read latest guidanc https co nuxuqmx (topic: 0)
# covid sobbing woman begs peru president save husband screams mr president go https co bzebqltvgh (topic: 0)
# australia announced significant changes studentvisa policies help internationalstudents affected https co oqdmphoc (topic: 0)
# assam police personnel check ids commuters guwahati amid covid induced lockdown https co ceaoifpw (topic: 0)
# join penkraft online cursive handwriting course penkraftcertifiedteacher vidya bhatt contact vidya https co flkmsfw (topic: 0)
# knock bbc often yesterday people died due covid amp given seconds coverage https co prbfusc (topic: 0)
# obasekiflagoff edoispdp line inecnigeria ncdcgov guidelines covid meters sitting https co kalasuge (topic: 0)
# covid ghana update avoid touching face mouth ears nose hand sanitized besafe (topic: 0)
# dailycaller understand peaceful protest seeing crowds covid concern obviously n https co tnitrnyvb (topic: 0)
# lots talk moment avoiding second waves covid countries already experiencing https co zldyhsxz (topic: 0)
# plasticfreejuly great reminder businesses forge ahead circular solutions sustainability ev https co kcyjampmx (topic: 0)
# arvindkumar_ias kms road crores covid lockdown time ts government releasing fun https co zjkwnyne (topic: 0)
# july covid admissions reported facilities public sector private secto https co udjtrxj (topic: 6)
# newham eastlondon businesses looking reopen need help advice covid loss trade free https co uipjnicsu (topic: 0)
# exercise compassion walk litter home reduce risks associated covid preventthespread https co nktzxiwks (topic: 0)
# dhaka street cleaners among risk contracting covid many continue work wit https co mflpvlae (topic: 0)
# saturdaythoughts life begin take shape give much energy dreams f https co liffzbvcky (topic: 0)
# breaking almost months ago stumbled covid scandal neck ever since https co zpitby (topic: 0)
# watch live minister health lizzie nkosi provides covid updates https co dcubifkm (topic: 0)
# wash hands washhands corona covid flattenthecurve washhands cancerfax https co kprqn (topic: 0)
# lot supporters think funny probably think preventable covid deaths fucking hilar https co ykngjjqxl (topic: 0)
# covid brought sharp focus fragile unequal scotland labour market really impact https co rrktngb (topic: 0)
# get key safeguard family invest health insurance starhealthinsurance insurance https co jldgshmskx (topic: 0)
# amid covid crisis hr professionals facing challenge redefining strategies leadership https co rqrfgxrw (topic: 0)
# shift towards agile responsive resilient supplychain begins keeping employees informed motiv https co jfmgoc (topic: 0)
# iitkharagpur develops portable low cost covid rapid test churn results one hour https co pthsecod (topic: 0)
# great opportunity covid recovery https co kvmvgcm (topic: 0)
# indiafightscorona safety hands quite literally visit https co dhkmcoapq stay https co gwtokxyb (topic: 0)
# covid made india favorable investment destination indiataxinsights magazine takes deep look https co xrhamhom (topic: 14)
# running last virtualpubquiz thursday th july pm live streaming facebook page https co njapquer (topic: 6)
# coronainfoch covid corona us forced labor world top surgical glove maker dru https co xtyjbaeh (topic: 0)
# covidvictoria good day small number recoveries still better wednesday covid (topic: 0)
# faroutakhtar happy get back work amid coronavirus pandemic covid https co htfryfszo (topic: 0)
# major breakthrough covid drug makes uk professors millionaires covid https co jpvvtgwje (topic: 0)
# something positive coming covid covid https co uxmjiita (topic: 5)
# truth government approaches covid around world clear rich lists r https co fgawsatmtu (topic: 0)
# really fascinating interview paul reid hse paulreiddublin hse thebusinessrte https co lvznllaf (topic: 0)
# terrible reality need face covid real wreaked havoc caused devastation w https co rzcbwopwo (topic: 0)
# response covid regulations amended allow prescriptions extended months allowi https co uzguplmm (topic: 0)
# jamesmelville evidence sad deaths covid please make mind https co fkdugiryyr (topic: 0)
# updated pm edt july modelling canadian covid epidemic based govcanhealth data usin https co yswgzdffyo (topic: 6)
# covid maine new covid cases total cases new deaths total deaths active cases hosp https co gdbpjtnjvv (topic: 18)
# update newly detected amp cured covid cases last hrs bmc area th july till https co vxfgxjadu (topic: 6)
# meat industry campaign cash flows officials seeking quash covid lawsuits https co pmgjkxjbs (topic: 0)
# israel top court rejects adalahcenter petition demanding israel implement covid protective guidelines pa https co pcwzrrrse (topic: 0)
# help slow spread covid identify risk cases sooner self reporting symptoms daily even https co ufaniezht (topic: 1)
# time living workingfromhome covid https co ganqtyfrk (topic: 0)
# today americans died covid overdeaths number people killed b https co zfnnuxu (topic: 0)
# gyms swimming pools reopen today covid excuse going window coronavirusuk covid obesity gym (topic: 0)
# help slow spread covid identify risk cases sooner self reporting symptoms daily even https co yinnsbz (topic: 1)
# first cruise ship sails german harbor since lockdown https co excpgrqld bigdata usa canada https co ohydajef (topic: 0)
# new statesman magazine covid roadtrip traffic https co lwrkwt (topic: 0)
# wow need listen life fair unfair others bbnaijalockdown alreadyvideo https co ntmwdrepjs (topic: 0)
# nactravel travelling coronavirus easy order get back families read https co pewezjmng (topic: 0)
# picture says covid privatehospitals corporatehospital https co luavplttck (topic: 0)
# covid cases india hours https co ldncjidxux (topic: 12)
# created crisis read socialimpact organisations emerged covid sup https co tjjyms (topic: 0)
# wondering get ppe gears wait ends offer reusable ppe kits cost effective p https co cvjddycy (topic: 0)
# lessons leadership covid ey joe dettmann amp micahmyer time wear company https co dahfznljx (topic: 0)
# get modern skincare tools website https co xjdvztvd contact details bio prices fro https co ecbpgtuef (topic: 0)
# borisjohnson man admits understanding covid soon enough missed first cobra dis https co kcidzdnme (topic: 0)
# coronainfoch covid corona india odisha covid https co vurenzwe (topic: 0)
# covid cases srinagar cases patients discharged last https co uvohhcssg (topic: 6)
# mentalhealth mindfulness coping difficult times get balance back try stres https co ckipfw (topic: 16)
# managing publicity news priyankagandhi slams govt covid handling letter cm https co munvavulw (topic: 0)
# coronavirusupdates covid patients recovered last hours taking recovery rate another h https co pklxyrapx (topic: 15)
# mom wrote covid lockdown gave freedom belly dance bellydance https co ubcxyt (topic: 0)
# mask covid https co plzdnoi (topic: 0)
# yup elections done w pretend getting better covid new cases toda https co goceemvi (topic: 0)
# coronavirusupdates indiafightscorona nearly cr samples tested far taking tests per million tpm https co awreevsyp (topic: 5)
# feel like pandemic vanish us elections november covid bbnaijalockdown covidnigeria (topic: 0)
# breaking xavi hernandez tested positive coronavirus covid__ covid xavi https co gsnsgtcafe (topic: 0)
# libertylockpod yr old male died covid motorcycle crash (topic: 0)
# grantshapps explain portugal left airbridge list spain still list desp https co xzyjyds (topic: 0)
# coronavirusupdates indiafightscorona india records highest ever lakh covid tests single da https co wgylufyhd (topic: 14)
# women sacrificial lambs covid childcare crisis via guardian covid localgov childcare https co bpcoywb (topic: 0)
# madhyapradesh cm chouhanshivraj tests positive covid coronavirusindia madhyapradeshcm (topic: 5)
# times changing covid caused enough disruption market opens market conditions https co uonbfgvn (topic: 0)
# covid multi organ killer please stay safe guys india country gonna escape https co pcnxsymu (topic: 0)
# time memes abantu bayadlana apha covid https co qnpscrek (topic: 0)
# could lifted directly downingstreet briefing covid https co fzdibrux (topic: 0)
# tedros adhanom ghebreyesus drtedros long covid circulating risk askin https co uitvogptt (topic: 13)
# youtuber mika salamanca arrested hawaii breaking covidquarantine rules tiktok vid covid https co xgzeykw (topic: 0)
# hong kong reported new covid cases today local cases biggest number since outbrea https co jvjusjux (topic: 18)
# date africa covid deaths pass mark amp cases pass almost recoveries pand https co chleadvjc (topic: 0)
# despicable sinclair plandemic covid https co lfocazuc (topic: 0)
# given recent news reported covid spikes resurgence france germany countries th https co irqisj (topic: 0)
# niagara falls tour boats highlight us canada stark covid divide https co vbagptoyo (topic: 0)
# active covid cases gujarat india increased last hours per hour data source mohfw (topic: 12)
# interesting interview paulreiddublin hselive rte right covid (topic: 0)
# really shocking article says lot huge economic impact covid well worth read https co pvrxdi (topic: 0)
# wear mask protect loved ones covid environment ecology coronavirus surroundyourselfwith https co kvcayyhfov (topic: 8)
# rajasthan reports new covid cases state tally coronavirus coronavirusupdates follow liv https co gcfu (topic: 18)
# finding light corona covid canon photographer photography selfie portrait flash reflection https co hxdkhhrgx (topic: 0)
# coronavirus public health england calls action obesity covid fight https co jkvqnip covid weight related diet (topic: 0)
# nigeria parte parte bbnaijalockdown covid jeethoiinsafki alreadyvideo هيون_الغماس https co hjhwdoxpej (topic: 0)
# traditional serbian food improvement immunity organism ficus carica aronia eff https co igxjtquuh (topic: 0)
# aishwaryaarjun recovers covid https co kqgqnupqvh (topic: 0)
# sturgeon playing fast loose covid statistics claim infection rate england w https co janpfp (topic: 0)
# apcnigeria officialapcng looking way extort money nigerians saynotonipostfee rihannaxtiwa https co dsmmmimgb (topic: 0)
# interesting look logistics covid vaccine distribution air cargo already stretched thin pandemic https co qqpztjobx (topic: 0)
# damnit celebrating la trinidad reduced covid positive cases yesterday https co qzdnrmqxy (topic: 18)
# kit kat girl puts charlie charlatan snp indyref scotland glasgow edinburgh covid https co pwfppipvsl (topic: 0)
# covid ruins vacation https co yxesetvyqt (topic: 0)
# covid case death reporting let know states thedemocrats think play electio https co cqmcngftlq (topic: 0)
# ipsosmori imperialcollege surveillance covid test kit arrived morning courier booked return mond https co ngkadmpyy (topic: 0)
# know times tough thank continued support lockdown covid thankyou https co tstlhacvp (topic: 0)
# dagovernment fights covid protects usthepeople anc fights wethepeople uses coronavirus https co wfguswsz (topic: 0)
# best animation production compan animation anime company illustration illustrator indian video covid https co irasjtltq (topic: 0)
# covid impact indians millions lost job migrants walked kms reach bjp govt response increases g https co fmsqmmfu (topic: 9)
# went back gym morning well laid social distancing observed well done organisers https co kaoccokgr (topic: 0)
# kashmir continues lockdown covid cases spike rise number symptomatic patients amp https co ylcltook (topic: 0)
# sure getting unbiased analysis scottish government performance scottish government advisers covid (topic: 0)
# economists talk mostly v shaped u shaped recovery bring complete guide incor https co wastehom (topic: 0)
# shocking covid https co jlfylyv (topic: 0)
# coronavirus updates muppets share top tips zoom etiquette coronavirus covid https co rfzixdfx (topic: 0)
# alert comprehensive town wide lockdown imposed kalimpong municipality seven days starting https co fdrivrmr (topic: 0)
# hope still remember elephantcement updateblog hushpuppy covid nigeria https co izjnwbcwxa (topic: 0)
# acceptable bump elbows quite enjoy covid (topic: 0)
# covid catalonia closes night life south korea spiking penny beginning drop yet (topic: 0)
# good reasons wear mask still wondering covid nhs wearadamnmask wearamaskplease https co yzwerobihx (topic: 8)
# maga supporters golfing turd meant making country great oh way https co xyimxjf (topic: 0)
# madhyapradesh chief minister chouhanshivraj tested positive covid india coronavirus https co macnyvjizu (topic: 5)
# nstnation health director general datuk dr noor hisham abdullah said ministry today identified two new https co wdlentiuz (topic: 18)
# nothing true victorian woman right masks bras covid https co dokillg (topic: 0)
# relieving scary actress preityzinta getting back work six months https co flpfxrc https co ytljgphw (topic: 0)
# covid causes loss smell non neuronal expression sars cov entry genes olfaory system suggest https co dgolvtaub (topic: 0)
# lanzarote partners birthday covid happened everything w https co yfanxrhxf (topic: 0)
# emergingmarkets cafs covid covid threatens survival south africa smes https co ccnuw https co nxbedac (topic: 0)
# iit kharagpur researchers claim developed portable covid testing device cost rs https co emrgwnyyx (topic: 0)
# lockdown charcoal drawings refocus anxiety plus p amp p taking https co wcefscbta (topic: 0)
# breaking attorney general informed secretary health draft circular instructions phi control https co ehxtflusd (topic: 0)
# video make cool mask pair old woollen socks https co mzpba borisjohnson https co vdwwbuzakg (topic: 0)
# port moresby confirms new covid cases last hrs nationals expat working govt dept https co oetoaroz (topic: 12)
# covid made us bitch happily bend take virus every orifice handing america https co hihxjzgh (topic: 0)
# tweaking traveling shot smh covid (topic: 0)
# mayoroflondon point rules masks shops sainsburys amp bandq enforcing wh https co jkeryfwr (topic: 0)
# skynews exploiting grieving mother spread fakenews deaths result cv resu https co imgnfols (topic: 0)
# gym whilst thecamps simply blag free discounted membership local gym saying gr https co phvvchedp (topic: 0)
# covid causes loss smell patients https co pusaquspj (topic: 0)
# pierre know easy lift knee ubaba jacob zumas neck try nxamalala zuma covid https co yexsggfimo (topic: 0)
# longer experienced freedom harder give america fight hands covid nomasks (topic: 0)
# update labuan covid case involved filipino https co ahiynrnh (topic: 6)
# sapoliceservice covid almost every weekend sophia town residents corner blackheath industrial stellen https co qvitftgdn (topic: 0)
# major breakthrough covid drug makes uk professors millionaires business guardian https co uccbzkwgi (topic: 0)
# classicozo rihannaxtiwa alreadyvideo bbnaijalockdown lucyourmama covid boy go kill https co zpeicchwo (topic: 0)
# achieve fit purpose finance function crisis covid coronavirus finance https co zatqiyseky (topic: 0)
